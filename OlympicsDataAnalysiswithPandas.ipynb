# %%
import pandas as pd

# %%
oo = pd.read_csv('./desktop/olympics.csv', skiprows=4)

# %%
oo.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
oo
# Out:
#           City  Edition      Sport       Discipline               Athlete  \
# 0       Athens     1896   Aquatics         Swimming         HAJOS, Alfred
# 1       Athens     1896   Aquatics         Swimming      HERSCHMANN, Otto
# 2       Athens     1896   Aquatics         Swimming     DRIVAS, Dimitrios
# 3       Athens     1896   Aquatics         Swimming    MALOKINIS, Ioannis
# 4       Athens     1896   Aquatics         Swimming    CHASAPIS, Spiridon
# ...        ...      ...        ...              ...                   ...
# 29211  Beijing     2008  Wrestling  Wrestling Gre-R        ENGLICH, Mirko
# 29212  Beijing     2008  Wrestling  Wrestling Gre-R  MIZGAITIS, Mindaugas
# 29213  Beijing     2008  Wrestling  Wrestling Gre-R       PATRIKEEV, Yuri
# 29214  Beijing     2008  Wrestling  Wrestling Gre-R         LOPEZ, Mijain
# 29215  Beijing     2008  Wrestling  Wrestling Gre-R        BAROEV, Khasan
#
#        NOC Gender                       Event Event_gender   Medal
# 0      HUN    Men              100m freestyle            M    Gold
# 1      AUT    Men              100m freestyle            M  Silver
# 2      GRE    Men  100m freestyle for sailors            M  Bronze
# 3      GRE    Men  100m freestyle for sailors            M    Gold
# 4      GRE    Men  100m freestyle for sailors            M  Silver
# ...    ...    ...                         ...          ...     ...
# 29211  GER    Men                   84 - 96kg            M  Silver
# 29212  LTU    Men                  96 - 120kg            M  Bronze
# 29213  ARM    Men                  96 - 120kg            M  Bronze
# 29214  CUB    Men                  96 - 120kg            M    Gold
# 29215  RUS    Men                  96 - 120kg            M  Silver
#
# [29216 rows x 10 columns]

# %%
oo[['City','Edition','Athlete']]
# Out:
#           City  Edition               Athlete
# 0       Athens     1896         HAJOS, Alfred
# 1       Athens     1896      HERSCHMANN, Otto
# 2       Athens     1896     DRIVAS, Dimitrios
# 3       Athens     1896    MALOKINIS, Ioannis
# 4       Athens     1896    CHASAPIS, Spiridon
# ...        ...      ...                   ...
# 29211  Beijing     2008        ENGLICH, Mirko
# 29212  Beijing     2008  MIZGAITIS, Mindaugas
# 29213  Beijing     2008       PATRIKEEV, Yuri
# 29214  Beijing     2008         LOPEZ, Mijain
# 29215  Beijing     2008        BAROEV, Khasan
#
# [29216 rows x 3 columns]

# %%
oo.shape
# Out:
# (29216, 10)

# %%
oo.shape[1]
# Out:
# 10

# %%
oo.head(5)
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
oo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29216 entries, 0 to 29215
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   City          29216 non-null  object
#  1   Edition       29216 non-null  int64
#  2   Sport         29216 non-null  object
#  3   Discipline    29216 non-null  object
#  4   Athlete       29216 non-null  object
#  5   NOC           29216 non-null  object
#  6   Gender        29216 non-null  object
#  7   Event         29216 non-null  object
#  8   Event_gender  29216 non-null  object
#  9   Medal         29216 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 2.2+ MB

# %%
oo.Edition.value_counts()
# Out:
# 2008    2042
# 2000    2015
# 2004    1998
# 1996    1859
# 1992    1705
# 1988    1546
# 1984    1459
# 1980    1387
# 1976    1305
# 1920    1298
# 1972    1185
# 1968    1031
# 1964    1010
# 1952     889
# 1912     885
# 1956     885
# 1924     884
# 1960     882
# 1936     875
# 1948     814
# 1908     804
# 1928     710
# 1932     615
# 1900     512
# 1904     470
# 1896     151
# Name: Edition, dtype: int64

# %%
oo.Gender.value_counts()
# Out:
# Men      21721
# Women     7495
# Name: Gender, dtype: int64

# %%
ath = oo.Athlete.sort_values()

# %%
oo.sort_values(by=['Edition', 'Athlete'])
# Out:
#           City  Edition       Sport    Discipline  \
# 7       Athens     1896    Aquatics      Swimming
# 82      Athens     1896  Gymnastics   Artistic G.
# 110     Athens     1896  Gymnastics   Artistic G.
# 111     Athens     1896  Gymnastics   Artistic G.
# 48      Athens     1896     Cycling  Cycling Road
# ...        ...      ...         ...           ...
# 28095  Beijing     2008  Equestrian      Dressage
# 28819  Beijing     2008     Sailing       Sailing
# 28977  Beijing     2008   Taekwondo     Taekwondo
# 28387  Beijing     2008  Gymnastics   Rhythmic G.
# 29007  Beijing     2008      Tennis        Tennis
#
#                               Athlete  NOC Gender                 Event  \
# 7                    ANDREOU, Joannis  GRE    Men       1200m freestyle
# 82           ANDRIAKOPOULOS, Nicolaos  GRE    Men         rope climbing
# 110          ANDRIAKOPOULOS, Nicolaos  GRE    Men   team, parallel bars
# 111            ATHANASOPOULOS, Spyros  GRE    Men   team, parallel bars
# 48                     BATTEL, Edward  GBR    Men  individual road race
# ...                               ...  ...    ...                   ...
# 28095  ZU-SAYN WITTGENSTEIN, Nathalie  DEN  Women                  team
# 28819                  ZUBARI, Shahar  ISR    Men     RS:X - Windsurfer
# 28977                 ZUBCIC, Martina  CRO  Women            49 - 57 kg
# 28387                  ZUEVA, Natalia  RUS  Women     group competition
# 29007                 ZVONAREVA, Vera  RUS  Women               singles
#
#       Event_gender   Medal
# 7                M  Silver
# 82               M    Gold
# 110              M  Silver
# 111              M  Silver
# 48               M  Bronze
# ...            ...     ...
# 28095            X  Bronze
# 28819            M  Bronze
# 28977            W  Bronze
# 28387            W    Gold
# 29007            W  Bronze
#
# [29216 rows x 10 columns]

# %%
oo.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
oo[(oo.Medal=='Gold') & (oo.Gender == 'Women')]
# Out:
#            City  Edition          Sport       Discipline  \
# 417       Paris     1900           Golf             Golf
# 641       Paris     1900         Tennis           Tennis
# 649       Paris     1900         Tennis           Tennis
# 710    St Louis     1904        Archery          Archery
# 713    St Louis     1904        Archery          Archery
# ...         ...      ...            ...              ...
# 29134   Beijing     2008  Weightlifting    Weightlifting
# 29147   Beijing     2008      Wrestling  Wrestling Free.
# 29155   Beijing     2008      Wrestling  Wrestling Free.
# 29163   Beijing     2008      Wrestling  Wrestling Free.
# 29171   Beijing     2008      Wrestling  Wrestling Free.
#
#                      Athlete  NOC Gender  \
# 417    ABBOTT, Margaret Ives  USA  Women
# 641        COOPER, Charlotte  GBR  Women
# 649        COOPER, Charlotte  GBR  Women
# 710    HOWELL, Matilda Scott  USA  Women
# 713    HOWELL, Matilda Scott  USA  Women
# ...                      ...  ...    ...
# 29134               CAO, Lei  CHN  Women
# 29147           HUYNH, Carol  CAN  Women
# 29155         YOSHIDA, Saori  JPN  Women
# 29163            ICHO, Kaori  JPN  Women
# 29171             WANG, Jiao  CHN  Women
#
#                                          Event Event_gender Medal
# 417                                 individual            W  Gold
# 641                              mixed doubles            X  Gold
# 649                                    singles            W  Gold
# 710    double columbia round (50y - 40y - 30y)            W  Gold
# 713          double national round (60y - 50y)            W  Gold
# ...                                        ...          ...   ...
# 29134                                     75kg            W  Gold
# 29147                                   - 48kg            W  Gold
# 29155                                48 - 55kg            W  Gold
# 29163                                55 - 63kg            W  Gold
# 29171                                63 - 72kg            W  Gold
#
# [2485 rows x 10 columns]

# %%
oo[oo.Athlete.str.contains('Florence')]
# Out:
#                         City  Edition      Sport      Discipline  \
# 1843                  London     1908    Skating  Figure skating
# 1848                  London     1908    Skating  Figure skating
# 4173                   Paris     1924   Aquatics        Swimming
# 8162                Helsinki     1952  Athletics       Athletics
# 9060   Melbourne / Stockholm     1956  Athletics       Athletics
# 10849                  Tokyo     1964  Athletics       Athletics
# 16817            Los Angeles     1984  Athletics       Athletics
# 18287                  Seoul     1988  Athletics       Athletics
# 18305                  Seoul     1988  Athletics       Athletics
# 18347                  Seoul     1988  Athletics       Athletics
# 18374                  Seoul     1988  Athletics       Athletics
#
#                                Athlete  NOC Gender                   Event  \
# 1843                   SYERS, Florence  GBR  Women              individual
# 1848                   SYERS, Florence  GBR  Women                   pairs
# 4173                  BARKER, Florence  GBR  Women  4x100m freestyle relay
# 8162        FOULDS-PAUL, June Florence  GBR  Women            4x100m relay
# 9060        FOULDS-PAUL, June Florence  GBR  Women            4x100m relay
# 10849  AMOORE-POLLOCK, Judith Florence  AUS  Women                    400m
# 16817        GRIFFITH-JOYNER, Florence  USA  Women                    200m
# 18287        GRIFFITH-JOYNER, Florence  USA  Women                    100m
# 18305        GRIFFITH-JOYNER, Florence  USA  Women                    200m
# 18347        GRIFFITH-JOYNER, Florence  USA  Women            4x100m relay
# 18374        GRIFFITH-JOYNER, Florence  USA  Women            4x400m relay
#
#       Event_gender   Medal
# 1843             W    Gold
# 1848             X  Bronze
# 4173             W  Silver
# 8162             W  Bronze
# 9060             W  Silver
# 10849            W  Bronze
# 16817            W  Silver
# 18287            W    Gold
# 18305            W    Gold
# 18347            W    Gold
# 18374            W  Silver

# %%
gbm = oo[(oo.Gender == 'Men') & (oo.Medal =='Gold') & (oo.Sport =='Badminton')]

# %%
gbm.sort_values(by='Athlete')
# Out:
#             City  Edition      Sport Discipline                  Athlete  NOC  \
# 20045  Barcelona     1992  Badminton  Badminton        BUDI KUSUMA, Alan  INA
# 23701     Sydney     2000  Badminton  Badminton            GUNAWAN, Tony  INA
# 25718     Athens     2004  Badminton  Badminton             HA, Tae-Kwon  KOR
# 25734     Athens     2004  Badminton  Badminton          HIDAYAT, Taufik  INA
# 21787    Atlanta     1996  Badminton  Badminton  HOYER-LARSEN, Poul Erik  DEN
# 23717     Sydney     2000  Badminton  Badminton              JI, Xinpeng  CHN
# 27725    Beijing     2008  Badminton  Badminton             KIDO, Markis  INA
# 25719     Athens     2004  Badminton  Badminton           KIM, Dong Moon  KOR
# 21773    Atlanta     1996  Badminton  Badminton           KIM, Dong Moon  KOR
# 20031  Barcelona     1992  Badminton  Badminton            KIM, Moon-Soo  KOR
# 27727    Beijing     2008  Badminton  Badminton             LEE, Yongdae  KOR
# 27741    Beijing     2008  Badminton  Badminton                 LIN, Dan  CHN
# 21771    Atlanta     1996  Badminton  Badminton     MAINAKY, Rexy Ronald  INA
# 20032  Barcelona     1992  Badminton  Badminton           PARK, Joo-Bong  KOR
# 27726    Beijing     2008  Badminton  Badminton         SETIAWAN, Hendra  INA
# 21772    Atlanta     1996  Badminton  Badminton    SUBAGJA, Ricky Achmad  INA
# 23702     Sydney     2000  Badminton  Badminton           WIJAYA, Candra  INA
# 25720     Athens     2004  Badminton  Badminton               ZHANG, Jun  CHN
# 23703     Sydney     2000  Badminton  Badminton               ZHANG, Jun  CHN
#
#       Gender    Event Event_gender Medal
# 20045    Men  singles            M  Gold
# 23701    Men  doubles            M  Gold
# 25718    Men  doubles            M  Gold
# 25734    Men  singles            M  Gold
# 21787    Men  singles            M  Gold
# 23717    Men  singles            M  Gold
# 27725    Men  doubles            M  Gold
# 25719    Men  doubles            M  Gold
# 21773    Men  doubles            X  Gold
# 20031    Men  doubles            M  Gold
# 27727    Men  doubles            X  Gold
# 27741    Men  singles            M  Gold
# 21771    Men  doubles            M  Gold
# 20032    Men  doubles            M  Gold
# 27726    Men  doubles            M  Gold
# 21772    Men  doubles            M  Gold
# 23702    Men  doubles            M  Gold
# 25720    Men  doubles            X  Gold
# 23703    Men  doubles            X  Gold

# %%
oo.index[100]
# Out:
# 100

# %%
oo.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
oo.set_index('Athlete')
# Out:
#                          City  Edition      Sport       Discipline  NOC  \
# Athlete
# HAJOS, Alfred          Athens     1896   Aquatics         Swimming  HUN
# HERSCHMANN, Otto       Athens     1896   Aquatics         Swimming  AUT
# DRIVAS, Dimitrios      Athens     1896   Aquatics         Swimming  GRE
# MALOKINIS, Ioannis     Athens     1896   Aquatics         Swimming  GRE
# CHASAPIS, Spiridon     Athens     1896   Aquatics         Swimming  GRE
# ...                       ...      ...        ...              ...  ...
# ENGLICH, Mirko        Beijing     2008  Wrestling  Wrestling Gre-R  GER
# MIZGAITIS, Mindaugas  Beijing     2008  Wrestling  Wrestling Gre-R  LTU
# PATRIKEEV, Yuri       Beijing     2008  Wrestling  Wrestling Gre-R  ARM
# LOPEZ, Mijain         Beijing     2008  Wrestling  Wrestling Gre-R  CUB
# BAROEV, Khasan        Beijing     2008  Wrestling  Wrestling Gre-R  RUS
#
#                      Gender                       Event Event_gender   Medal
# Athlete
# HAJOS, Alfred           Men              100m freestyle            M    Gold
# HERSCHMANN, Otto        Men              100m freestyle            M  Silver
# DRIVAS, Dimitrios       Men  100m freestyle for sailors            M  Bronze
# MALOKINIS, Ioannis      Men  100m freestyle for sailors            M    Gold
# CHASAPIS, Spiridon      Men  100m freestyle for sailors            M  Silver
# ...                     ...                         ...          ...     ...
# ENGLICH, Mirko          Men                   84 - 96kg            M  Silver
# MIZGAITIS, Mindaugas    Men                  96 - 120kg            M  Bronze
# PATRIKEEV, Yuri         Men                  96 - 120kg            M  Bronze
# LOPEZ, Mijain           Men                  96 - 120kg            M    Gold
# BAROEV, Khasan          Men                  96 - 120kg            M  Silver
#
# [29216 rows x 9 columns]

# %%
oo.head()
# Out:
#                       City  Edition     Sport Discipline  NOC Gender  \
# Athlete
# HAJOS, Alfred       Athens     1896  Aquatics   Swimming  HUN    Men
# HERSCHMANN, Otto    Athens     1896  Aquatics   Swimming  AUT    Men
# DRIVAS, Dimitrios   Athens     1896  Aquatics   Swimming  GRE    Men
# MALOKINIS, Ioannis  Athens     1896  Aquatics   Swimming  GRE    Men
# CHASAPIS, Spiridon  Athens     1896  Aquatics   Swimming  GRE    Men
#
#                                          Event Event_gender   Medal
# Athlete
# HAJOS, Alfred                   100m freestyle            M    Gold
# HERSCHMANN, Otto                100m freestyle            M  Silver
# DRIVAS, Dimitrios   100m freestyle for sailors            M  Bronze
# MALOKINIS, Ioannis  100m freestyle for sailors            M    Gold
# CHASAPIS, Spiridon  100m freestyle for sailors            M  Silver

# %%
ath = oo.reset_index(inplace=True)

# %%
oo
# Out:
#        level_0  index               Athlete     City  Edition      Sport  \
# 0            0      0         HAJOS, Alfred   Athens     1896   Aquatics
# 1            1      1      HERSCHMANN, Otto   Athens     1896   Aquatics
# 2            2      2     DRIVAS, Dimitrios   Athens     1896   Aquatics
# 3            3      3    MALOKINIS, Ioannis   Athens     1896   Aquatics
# 4            4      4    CHASAPIS, Spiridon   Athens     1896   Aquatics
# ...        ...    ...                   ...      ...      ...        ...
# 29211    29211  29211        ENGLICH, Mirko  Beijing     2008  Wrestling
# 29212    29212  29212  MIZGAITIS, Mindaugas  Beijing     2008  Wrestling
# 29213    29213  29213       PATRIKEEV, Yuri  Beijing     2008  Wrestling
# 29214    29214  29214         LOPEZ, Mijain  Beijing     2008  Wrestling
# 29215    29215  29215        BAROEV, Khasan  Beijing     2008  Wrestling
#
#             Discipline  NOC Gender                       Event Event_gender  \
# 0             Swimming  HUN    Men              100m freestyle            M
# 1             Swimming  AUT    Men              100m freestyle            M
# 2             Swimming  GRE    Men  100m freestyle for sailors            M
# 3             Swimming  GRE    Men  100m freestyle for sailors            M
# 4             Swimming  GRE    Men  100m freestyle for sailors            M
# ...                ...  ...    ...                         ...          ...
# 29211  Wrestling Gre-R  GER    Men                   84 - 96kg            M
# 29212  Wrestling Gre-R  LTU    Men                  96 - 120kg            M
# 29213  Wrestling Gre-R  ARM    Men                  96 - 120kg            M
# 29214  Wrestling Gre-R  CUB    Men                  96 - 120kg            M
# 29215  Wrestling Gre-R  RUS    Men                  96 - 120kg            M
#
#         Medal
# 0        Gold
# 1      Silver
# 2      Bronze
# 3        Gold
# 4      Silver
# ...       ...
# 29211  Silver
# 29212  Bronze
# 29213  Bronze
# 29214    Gold
# 29215  Silver
#
# [29216 rows x 12 columns]

# %%
ath

# %%
ath

# %%
oo
# Out:
#        level_0  index               Athlete     City  Edition      Sport  \
# 0            0      0         HAJOS, Alfred   Athens     1896   Aquatics
# 1            1      1      HERSCHMANN, Otto   Athens     1896   Aquatics
# 2            2      2     DRIVAS, Dimitrios   Athens     1896   Aquatics
# 3            3      3    MALOKINIS, Ioannis   Athens     1896   Aquatics
# 4            4      4    CHASAPIS, Spiridon   Athens     1896   Aquatics
# ...        ...    ...                   ...      ...      ...        ...
# 29211    29211  29211        ENGLICH, Mirko  Beijing     2008  Wrestling
# 29212    29212  29212  MIZGAITIS, Mindaugas  Beijing     2008  Wrestling
# 29213    29213  29213       PATRIKEEV, Yuri  Beijing     2008  Wrestling
# 29214    29214  29214         LOPEZ, Mijain  Beijing     2008  Wrestling
# 29215    29215  29215        BAROEV, Khasan  Beijing     2008  Wrestling
#
#             Discipline  NOC Gender                       Event Event_gender  \
# 0             Swimming  HUN    Men              100m freestyle            M
# 1             Swimming  AUT    Men              100m freestyle            M
# 2             Swimming  GRE    Men  100m freestyle for sailors            M
# 3             Swimming  GRE    Men  100m freestyle for sailors            M
# 4             Swimming  GRE    Men  100m freestyle for sailors            M
# ...                ...  ...    ...                         ...          ...
# 29211  Wrestling Gre-R  GER    Men                   84 - 96kg            M
# 29212  Wrestling Gre-R  LTU    Men                  96 - 120kg            M
# 29213  Wrestling Gre-R  ARM    Men                  96 - 120kg            M
# 29214  Wrestling Gre-R  CUB    Men                  96 - 120kg            M
# 29215  Wrestling Gre-R  RUS    Men                  96 - 120kg            M
#
#         Medal
# 0        Gold
# 1      Silver
# 2      Bronze
# 3        Gold
# 4      Silver
# ...       ...
# 29211  Silver
# 29212  Bronze
# 29213  Bronze
# 29214    Gold
# 29215  Silver
#
# [29216 rows x 12 columns]

# %%
oo.head()
# Out:
#    level_0  index             Athlete    City  Edition     Sport Discipline  \
# 0        0      0       HAJOS, Alfred  Athens     1896  Aquatics   Swimming
# 1        1      1    HERSCHMANN, Otto  Athens     1896  Aquatics   Swimming
# 2        2      2   DRIVAS, Dimitrios  Athens     1896  Aquatics   Swimming
# 3        3      3  MALOKINIS, Ioannis  Athens     1896  Aquatics   Swimming
# 4        4      4  CHASAPIS, Spiridon  Athens     1896  Aquatics   Swimming
#
#    NOC Gender                       Event Event_gender   Medal
# 0  HUN    Men              100m freestyle            M    Gold
# 1  AUT    Men              100m freestyle            M  Silver
# 2  GRE    Men  100m freestyle for sailors            M  Bronze
# 3  GRE    Men  100m freestyle for sailors            M    Gold
# 4  GRE    Men  100m freestyle for sailors            M  Silver

# %%
oo.head()
# Out:
#                     level_0  index    City  Edition     Sport Discipline  NOC  \
# Athlete
# HAJOS, Alfred             0      0  Athens     1896  Aquatics   Swimming  HUN
# HERSCHMANN, Otto          1      1  Athens     1896  Aquatics   Swimming  AUT
# DRIVAS, Dimitrios         2      2  Athens     1896  Aquatics   Swimming  GRE
# MALOKINIS, Ioannis        3      3  Athens     1896  Aquatics   Swimming  GRE
# CHASAPIS, Spiridon        4      4  Athens     1896  Aquatics   Swimming  GRE
#
#                    Gender                       Event Event_gender   Medal
# Athlete
# HAJOS, Alfred         Men              100m freestyle            M    Gold
# HERSCHMANN, Otto      Men              100m freestyle            M  Silver
# DRIVAS, Dimitrios     Men  100m freestyle for sailors            M  Bronze
# MALOKINIS, Ioannis    Men  100m freestyle for sailors            M    Gold
# CHASAPIS, Spiridon    Men  100m freestyle for sailors            M  Silver

# %%
oo
# Out:
#                       level_0  index     City  Edition      Sport  \
# Athlete
# HAJOS, Alfred               0      0   Athens     1896   Aquatics
# HERSCHMANN, Otto            1      1   Athens     1896   Aquatics
# DRIVAS, Dimitrios           2      2   Athens     1896   Aquatics
# MALOKINIS, Ioannis          3      3   Athens     1896   Aquatics
# CHASAPIS, Spiridon          4      4   Athens     1896   Aquatics
# ...                       ...    ...      ...      ...        ...
# ENGLICH, Mirko          29211  29211  Beijing     2008  Wrestling
# MIZGAITIS, Mindaugas    29212  29212  Beijing     2008  Wrestling
# PATRIKEEV, Yuri         29213  29213  Beijing     2008  Wrestling
# LOPEZ, Mijain           29214  29214  Beijing     2008  Wrestling
# BAROEV, Khasan          29215  29215  Beijing     2008  Wrestling
#
#                            Discipline  NOC Gender                       Event  \
# Athlete
# HAJOS, Alfred                Swimming  HUN    Men              100m freestyle
# HERSCHMANN, Otto             Swimming  AUT    Men              100m freestyle
# DRIVAS, Dimitrios            Swimming  GRE    Men  100m freestyle for sailors
# MALOKINIS, Ioannis           Swimming  GRE    Men  100m freestyle for sailors
# CHASAPIS, Spiridon           Swimming  GRE    Men  100m freestyle for sailors
# ...                               ...  ...    ...                         ...
# ENGLICH, Mirko        Wrestling Gre-R  GER    Men                   84 - 96kg
# MIZGAITIS, Mindaugas  Wrestling Gre-R  LTU    Men                  96 - 120kg
# PATRIKEEV, Yuri       Wrestling Gre-R  ARM    Men                  96 - 120kg
# LOPEZ, Mijain         Wrestling Gre-R  CUB    Men                  96 - 120kg
# BAROEV, Khasan        Wrestling Gre-R  RUS    Men                  96 - 120kg
#
#                      Event_gender   Medal
# Athlete
# HAJOS, Alfred                   M    Gold
# HERSCHMANN, Otto                M  Silver
# DRIVAS, Dimitrios               M  Bronze
# MALOKINIS, Ioannis              M    Gold
# CHASAPIS, Spiridon              M  Silver
# ...                           ...     ...
# ENGLICH, Mirko                  M  Silver
# MIZGAITIS, Mindaugas            M  Bronze
# PATRIKEEV, Yuri                 M  Bronze
# LOPEZ, Mijain                   M    Gold
# BAROEV, Khasan                  M  Silver
#
# [29216 rows x 11 columns]

# %%
del oo['level_0']

# %%
oo.head()
# Out:
#                     index    City  Edition     Sport Discipline  NOC Gender  \
# Athlete
# HAJOS, Alfred           0  Athens     1896  Aquatics   Swimming  HUN    Men
# HERSCHMANN, Otto        1  Athens     1896  Aquatics   Swimming  AUT    Men
# DRIVAS, Dimitrios       2  Athens     1896  Aquatics   Swimming  GRE    Men
# MALOKINIS, Ioannis      3  Athens     1896  Aquatics   Swimming  GRE    Men
# CHASAPIS, Spiridon      4  Athens     1896  Aquatics   Swimming  GRE    Men
#
#                                          Event Event_gender   Medal
# Athlete
# HAJOS, Alfred                   100m freestyle            M    Gold
# HERSCHMANN, Otto                100m freestyle            M  Silver
# DRIVAS, Dimitrios   100m freestyle for sailors            M  Bronze
# MALOKINIS, Ioannis  100m freestyle for sailors            M    Gold
# CHASAPIS, Spiridon  100m freestyle for sailors            M  Silver

# %%
ath = oo

# %%
ath
# Out:
#                       index     City  Edition      Sport       Discipline  \
# Athlete
# HAJOS, Alfred             0   Athens     1896   Aquatics         Swimming
# HERSCHMANN, Otto          1   Athens     1896   Aquatics         Swimming
# DRIVAS, Dimitrios         2   Athens     1896   Aquatics         Swimming
# MALOKINIS, Ioannis        3   Athens     1896   Aquatics         Swimming
# CHASAPIS, Spiridon        4   Athens     1896   Aquatics         Swimming
# ...                     ...      ...      ...        ...              ...
# ENGLICH, Mirko        29211  Beijing     2008  Wrestling  Wrestling Gre-R
# MIZGAITIS, Mindaugas  29212  Beijing     2008  Wrestling  Wrestling Gre-R
# PATRIKEEV, Yuri       29213  Beijing     2008  Wrestling  Wrestling Gre-R
# LOPEZ, Mijain         29214  Beijing     2008  Wrestling  Wrestling Gre-R
# BAROEV, Khasan        29215  Beijing     2008  Wrestling  Wrestling Gre-R
#
#                       NOC Gender                       Event Event_gender  \
# Athlete
# HAJOS, Alfred         HUN    Men              100m freestyle            M
# HERSCHMANN, Otto      AUT    Men              100m freestyle            M
# DRIVAS, Dimitrios     GRE    Men  100m freestyle for sailors            M
# MALOKINIS, Ioannis    GRE    Men  100m freestyle for sailors            M
# CHASAPIS, Spiridon    GRE    Men  100m freestyle for sailors            M
# ...                   ...    ...                         ...          ...
# ENGLICH, Mirko        GER    Men                   84 - 96kg            M
# MIZGAITIS, Mindaugas  LTU    Men                  96 - 120kg            M
# PATRIKEEV, Yuri       ARM    Men                  96 - 120kg            M
# LOPEZ, Mijain         CUB    Men                  96 - 120kg            M
# BAROEV, Khasan        RUS    Men                  96 - 120kg            M
#
#                        Medal
# Athlete
# HAJOS, Alfred           Gold
# HERSCHMANN, Otto      Silver
# DRIVAS, Dimitrios     Bronze
# MALOKINIS, Ioannis      Gold
# CHASAPIS, Spiridon    Silver
# ...                      ...
# ENGLICH, Mirko        Silver
# MIZGAITIS, Mindaugas  Bronze
# PATRIKEEV, Yuri       Bronze
# LOPEZ, Mijain           Gold
# BAROEV, Khasan        Silver
#
# [29216 rows x 10 columns]

# %%
ath.sort_index(inplace=True)

# %%
ath
# Out:
#                           index      City  Edition       Sport   Discipline  \
# Athlete
# AABYE, Edgar                651     Paris     1900  Tug of War   Tug of War
# AALTONEN, Arvo Ossian      2849   Antwerp     1920    Aquatics     Swimming
# AALTONEN, Arvo Ossian      2852   Antwerp     1920    Aquatics     Swimming
# AALTONEN, Paavo Johannes   7773    London     1948  Gymnastics  Artistic G.
# AALTONEN, Paavo Johannes   7730    London     1948  Gymnastics  Artistic G.
# ...                         ...       ...      ...         ...          ...
# ÖSTMO, Ole                  603     Paris     1900    Shooting     Shooting
# ÖSTMO, Ole                  608     Paris     1900    Shooting     Shooting
# ÖSTMO, Ole                  621     Paris     1900    Shooting     Shooting
# ÖSTMO, Ole                  596     Paris     1900    Shooting     Shooting
# ÖSTRAND, Per-Olof          8051  Helsinki     1952    Aquatics     Swimming
#
#                           NOC Gender                          Event  \
# Athlete
# AABYE, Edgar              ZZX    Men                     tug of war
# AALTONEN, Arvo Ossian     FIN    Men              200m breaststroke
# AALTONEN, Arvo Ossian     FIN    Men              400m breaststroke
# AALTONEN, Paavo Johannes  FIN    Men                          vault
# AALTONEN, Paavo Johannes  FIN    Men               team competition
# ...                       ...    ...                            ...
# ÖSTMO, Ole                NOR    Men        army rifle, 300m, prone
# ÖSTMO, Ole                NOR    Men     army rifle, 300m, standing
# ÖSTMO, Ole                NOR    Men               free rifle, team
# ÖSTMO, Ole                NOR    Men  army rifle, 300m, 3 positions
# ÖSTRAND, Per-Olof         SWE    Men                 400m freestyle
#
#                          Event_gender   Medal
# Athlete
# AABYE, Edgar                        M    Gold
# AALTONEN, Arvo Ossian               M  Bronze
# AALTONEN, Arvo Ossian               M  Bronze
# AALTONEN, Paavo Johannes            M    Gold
# AALTONEN, Paavo Johannes            M    Gold
# ...                               ...     ...
# ÖSTMO, Ole                          M  Bronze
# ÖSTMO, Ole                          M  Silver
# ÖSTMO, Ole                          M  Silver
# ÖSTMO, Ole                          M  Bronze
# ÖSTRAND, Per-Olof                   M  Bronze
#
# [29216 rows x 10 columns]

# %%
ath.loc['BOLT, Usain']
# Out:
#              index     City  Edition      Sport Discipline  NOC Gender  \
# Athlete
# BOLT, Usain  27570  Beijing     2008  Athletics  Athletics  JAM    Men
# BOLT, Usain  27603  Beijing     2008  Athletics  Athletics  JAM    Men
# BOLT, Usain  27552  Beijing     2008  Athletics  Athletics  JAM    Men
#
#                     Event Event_gender Medal
# Athlete
# BOLT, Usain          200m            M  Gold
# BOLT, Usain  4x100m relay            M  Gold
# BOLT, Usain          100m            M  Gold

# %%
ath.iloc[1:4]
# Out:
#                           index     City  Edition       Sport   Discipline  \
# Athlete
# AALTONEN, Arvo Ossian      2849  Antwerp     1920    Aquatics     Swimming
# AALTONEN, Arvo Ossian      2852  Antwerp     1920    Aquatics     Swimming
# AALTONEN, Paavo Johannes   7773   London     1948  Gymnastics  Artistic G.
#
#                           NOC Gender              Event Event_gender   Medal
# Athlete
# AALTONEN, Arvo Ossian     FIN    Men  200m breaststroke            M  Bronze
# AALTONEN, Arvo Ossian     FIN    Men  400m breaststroke            M  Bronze
# AALTONEN, Paavo Johannes  FIN    Men              vault            M    Gold

# %%
ath
# Out:
#                           index      City  Edition       Sport   Discipline  \
# Athlete
# AABYE, Edgar                651     Paris     1900  Tug of War   Tug of War
# AALTONEN, Arvo Ossian      2849   Antwerp     1920    Aquatics     Swimming
# AALTONEN, Arvo Ossian      2852   Antwerp     1920    Aquatics     Swimming
# AALTONEN, Paavo Johannes   7773    London     1948  Gymnastics  Artistic G.
# AALTONEN, Paavo Johannes   7730    London     1948  Gymnastics  Artistic G.
# ...                         ...       ...      ...         ...          ...
# ÖSTMO, Ole                  603     Paris     1900    Shooting     Shooting
# ÖSTMO, Ole                  608     Paris     1900    Shooting     Shooting
# ÖSTMO, Ole                  621     Paris     1900    Shooting     Shooting
# ÖSTMO, Ole                  596     Paris     1900    Shooting     Shooting
# ÖSTRAND, Per-Olof          8051  Helsinki     1952    Aquatics     Swimming
#
#                           NOC Gender                          Event  \
# Athlete
# AABYE, Edgar              ZZX    Men                     tug of war
# AALTONEN, Arvo Ossian     FIN    Men              200m breaststroke
# AALTONEN, Arvo Ossian     FIN    Men              400m breaststroke
# AALTONEN, Paavo Johannes  FIN    Men                          vault
# AALTONEN, Paavo Johannes  FIN    Men               team competition
# ...                       ...    ...                            ...
# ÖSTMO, Ole                NOR    Men        army rifle, 300m, prone
# ÖSTMO, Ole                NOR    Men     army rifle, 300m, standing
# ÖSTMO, Ole                NOR    Men               free rifle, team
# ÖSTMO, Ole                NOR    Men  army rifle, 300m, 3 positions
# ÖSTRAND, Per-Olof         SWE    Men                 400m freestyle
#
#                          Event_gender   Medal
# Athlete
# AABYE, Edgar                        M    Gold
# AALTONEN, Arvo Ossian               M  Bronze
# AALTONEN, Arvo Ossian               M  Bronze
# AALTONEN, Paavo Johannes            M    Gold
# AALTONEN, Paavo Johannes            M    Gold
# ...                               ...     ...
# ÖSTMO, Ole                          M  Bronze
# ÖSTMO, Ole                          M  Silver
# ÖSTMO, Ole                          M  Silver
# ÖSTMO, Ole                          M  Bronze
# ÖSTRAND, Per-Olof                   M  Bronze
#
# [29216 rows x 10 columns]

# %%
ath.reset_index(inplace=True)

# %%
ath
# Out:
#                         Athlete  index      City  Edition       Sport  \
# 0                  AABYE, Edgar    651     Paris     1900  Tug of War
# 1         AALTONEN, Arvo Ossian   2849   Antwerp     1920    Aquatics
# 2         AALTONEN, Arvo Ossian   2852   Antwerp     1920    Aquatics
# 3      AALTONEN, Paavo Johannes   7773    London     1948  Gymnastics
# 4      AALTONEN, Paavo Johannes   7730    London     1948  Gymnastics
# ...                         ...    ...       ...      ...         ...
# 29211                ÖSTMO, Ole    603     Paris     1900    Shooting
# 29212                ÖSTMO, Ole    608     Paris     1900    Shooting
# 29213                ÖSTMO, Ole    621     Paris     1900    Shooting
# 29214                ÖSTMO, Ole    596     Paris     1900    Shooting
# 29215         ÖSTRAND, Per-Olof   8051  Helsinki     1952    Aquatics
#
#         Discipline  NOC Gender                          Event Event_gender  \
# 0       Tug of War  ZZX    Men                     tug of war            M
# 1         Swimming  FIN    Men              200m breaststroke            M
# 2         Swimming  FIN    Men              400m breaststroke            M
# 3      Artistic G.  FIN    Men                          vault            M
# 4      Artistic G.  FIN    Men               team competition            M
# ...            ...  ...    ...                            ...          ...
# 29211     Shooting  NOR    Men        army rifle, 300m, prone            M
# 29212     Shooting  NOR    Men     army rifle, 300m, standing            M
# 29213     Shooting  NOR    Men               free rifle, team            M
# 29214     Shooting  NOR    Men  army rifle, 300m, 3 positions            M
# 29215     Swimming  SWE    Men                 400m freestyle            M
#
#         Medal
# 0        Gold
# 1      Bronze
# 2      Bronze
# 3        Gold
# 4        Gold
# ...       ...
# 29211  Bronze
# 29212  Silver
# 29213  Silver
# 29214  Bronze
# 29215  Bronze
#
# [29216 rows x 11 columns]

# %%
ath.iloc[[1542, 2390, 6000, 15000]]
# Out:
#                     Athlete  index       City  Edition       Sport  \
# 1542         BAYRAK, Mithat  10666       Rome     1960   Wrestling
# 2390   BOGINSKAYA, Svetlana  18925      Seoul     1988  Gymnastics
# 6000        DORADO, Natalia  20751  Barcelona     1992      Hockey
# 15000      LISITSKY, Viktor  11273      Tokyo     1964  Gymnastics
#
#             Discipline  NOC Gender                     Event Event_gender  \
# 1542   Wrestling Gre-R  TUR    Men  67 - 73kg (welterweight)            M
# 2390       Artistic G.  URS  Women                     vault            W
# 6000            Hockey  ESP  Women                    hockey            W
# 15000      Artistic G.  URS    Men           floor exercises            M
#
#         Medal
# 1542     Gold
# 2390     Gold
# 6000     Gold
# 15000  Silver

# %%
noc = pd.read_csv('./desktop/Summer Olympic medallists 1896 to 2008 - IOC COUNTRY CODES.csv')

# %%
noc[noc['Country'] != noc['Country.1']]
# Out:
# Empty DataFrame
# Columns: [Country, Int Olympic Committee code, ISO code, Country.1]
# Index: []

# %%
noc
# Out:
#              Country Int Olympic Committee code ISO code        Country.1
# 0        Afghanistan                        AFG       AF      Afghanistan
# 1            Albania                        ALB       AL          Albania
# 2            Algeria                        ALG       DZ          Algeria
# 3    American Samoa*                        ASA       AS  American Samoa*
# 4            Andorra                        AND       AD          Andorra
# ..               ...                        ...      ...              ...
# 196          Vietnam                        VIE       VN          Vietnam
# 197  Virgin Islands*                        ISV       VI  Virgin Islands*
# 198            Yemen                        YEM       YE            Yemen
# 199           Zambia                        ZAM       ZM           Zambia
# 200         Zimbabwe                        ZIM       ZW         Zimbabwe
#
# [201 rows x 4 columns]

# %%
noc.set_index('Int Olympic Committee code', inplace=True)

# %%
noc.head()
# Out:
#                                     Country ISO code        Country.1
# Int Olympic Committee code
# AFG                             Afghanistan       AF      Afghanistan
# ALB                                 Albania       AL          Albania
# ALG                                 Algeria       DZ          Algeria
# ASA                         American Samoa*       AS  American Samoa*
# AND                                 Andorra       AD          Andorra

# %%
oo
# Out:
#                         Athlete  index      City  Edition       Sport  \
# 0                  AABYE, Edgar    651     Paris     1900  Tug of War
# 1         AALTONEN, Arvo Ossian   2849   Antwerp     1920    Aquatics
# 2         AALTONEN, Arvo Ossian   2852   Antwerp     1920    Aquatics
# 3      AALTONEN, Paavo Johannes   7773    London     1948  Gymnastics
# 4      AALTONEN, Paavo Johannes   7730    London     1948  Gymnastics
# ...                         ...    ...       ...      ...         ...
# 29211                ÖSTMO, Ole    603     Paris     1900    Shooting
# 29212                ÖSTMO, Ole    608     Paris     1900    Shooting
# 29213                ÖSTMO, Ole    621     Paris     1900    Shooting
# 29214                ÖSTMO, Ole    596     Paris     1900    Shooting
# 29215         ÖSTRAND, Per-Olof   8051  Helsinki     1952    Aquatics
#
#         Discipline  NOC Gender                          Event Event_gender  \
# 0       Tug of War  ZZX    Men                     tug of war            M
# 1         Swimming  FIN    Men              200m breaststroke            M
# 2         Swimming  FIN    Men              400m breaststroke            M
# 3      Artistic G.  FIN    Men                          vault            M
# 4      Artistic G.  FIN    Men               team competition            M
# ...            ...  ...    ...                            ...          ...
# 29211     Shooting  NOR    Men        army rifle, 300m, prone            M
# 29212     Shooting  NOR    Men     army rifle, 300m, standing            M
# 29213     Shooting  NOR    Men               free rifle, team            M
# 29214     Shooting  NOR    Men  army rifle, 300m, 3 positions            M
# 29215     Swimming  SWE    Men                 400m freestyle            M
#
#         Medal
# 0        Gold
# 1      Bronze
# 2      Bronze
# 3        Gold
# 4        Gold
# ...       ...
# 29211  Bronze
# 29212  Silver
# 29213  Silver
# 29214  Bronze
# 29215  Bronze
#
# [29216 rows x 11 columns]

# %%
oo.groupby('Edition')

# %%
type(oo.groupby('Edition'))
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
list(oo.groupby('Edition'))
# Out:
# [(1896,
#                           Athlete  index    City  Edition       Sport  \
#   585            ANDREOU, Joannis      7  Athens     1896    Aquatics
#   596    ANDRIAKOPOULOS, Nicolaos    110  Athens     1896  Gymnastics
#   597    ANDRIAKOPOULOS, Nicolaos     82  Athens     1896  Gymnastics
#   922      ATHANASOPOULOS, Spyros    111  Athens     1896  Gymnastics
#   1466             BATTEL, Edward     48  Athens     1896     Cycling
#   ...                         ...    ...     ...      ...         ...
#   28458        XENAKIS, Thomasios     83  Athens     1896  Gymnastics
#   28459        XENAKIS, Thomasios    113  Athens     1896  Gymnastics
#   29165             ZUTTER, Louis     75  Athens     1896  Gymnastics
#   29166             ZUTTER, Louis    116  Athens     1896  Gymnastics
#   29167             ZUTTER, Louis     76  Athens     1896  Gymnastics
#
#            Discipline  NOC Gender                 Event Event_gender   Medal
#   585        Swimming  GRE    Men       1200m freestyle            M  Silver
#   596     Artistic G.  GRE    Men   team, parallel bars            M  Silver
#   597     Artistic G.  GRE    Men         rope climbing            M    Gold
#   922     Artistic G.  GRE    Men   team, parallel bars            M  Silver
#   1466   Cycling Road  GBR    Men  individual road race            M  Bronze
#   ...             ...  ...    ...                   ...          ...     ...
#   28458   Artistic G.  GRE    Men         rope climbing            M  Silver
#   28459   Artistic G.  GRE    Men   team, parallel bars            M  Silver
#   29165   Artistic G.  SUI    Men         parallel bars            M  Silver
#   29166   Artistic G.  SUI    Men                 vault            M  Silver
#   29167   Artistic G.  SUI    Men          pommel horse            M    Gold
#
#   [151 rows x 11 columns]),
#  (1900,
#                        Athlete  index   City  Edition       Sport  Discipline  \
#   0               AABYE, Edgar    651  Paris     1900  Tug of War  Tug of War
#   39     ABBOTT, Margaret Ives    417  Paris     1900        Golf        Golf
#   66              ABELL, Louis    443  Paris     1900      Rowing      Rowing
#   225         AITOFF, Vladimir    502  Paris     1900       Rugby       Rugby
#   274               ALBERT, A.    503  Paris     1900       Rugby       Rugby
#   ...                      ...    ...    ...      ...         ...         ...
#   28883  ZEALLEY, James Edward    399  Paris     1900    Football    Football
#   29211             ÖSTMO, Ole    603  Paris     1900    Shooting    Shooting
#   29212             ÖSTMO, Ole    608  Paris     1900    Shooting    Shooting
#   29213             ÖSTMO, Ole    621  Paris     1900    Shooting    Shooting
#   29214             ÖSTMO, Ole    596  Paris     1900    Shooting    Shooting
#
#          NOC Gender                          Event Event_gender   Medal
#   0      ZZX    Men                     tug of war            M    Gold
#   39     USA  Women                     individual            W    Gold
#   66     USA    Men       eight with coxswain (8+)            M    Gold
#   225    FRA    Men                          rugby            M    Gold
#   274    FRA    Men                          rugby            M    Gold
#   ...    ...    ...                            ...          ...     ...
#   28883  GBR    Men                       football            M    Gold
#   29211  NOR    Men        army rifle, 300m, prone            M  Bronze
#   29212  NOR    Men     army rifle, 300m, standing            M  Silver
#   29213  NOR    Men               free rifle, team            M  Silver
#   29214  NOR    Men  army rifle, 300m, 3 positions            M  Bronze
#
#   [512 rows x 11 columns]),
#  (1904,
#                     Athlete  index      City  Edition      Sport  \
#   67           ABELL, Louis   1046  St Louis     1904     Rowing
#   119       ADAMS, Edgar H.    669  St Louis     1904   Aquatics
#   400         AMAN, Charles   1072  St Louis     1904     Rowing
#   589    ANDREWS, Arthur F.    854  St Louis     1904    Cycling
#   590    ANDREWS, Arthur F.    855  St Louis     1904    Cycling
#   ...                   ...    ...       ...      ...        ...
#   28686               YOUNG   1030  St Louis     1904   Lacrosse
#   28687       YOUNG, Albert    833  St Louis     1904     Boxing
#   28760    ZACHARIAS, Georg    683  St Louis     1904   Aquatics
#   28761    ZACHARIAS, Georg    670  St Louis     1904   Aquatics
#   29085      ZIRKEL, Albert   1127  St Louis     1904  Wrestling
#
#               Discipline  NOC Gender                           Event  \
#   67              Rowing  USA    Men        eight with coxswain (8+)
#   119             Diving  USA    Men             plunge for distance
#   400             Rowing  USA    Men      four without coxswain (4-)
#   589      Cycling Track  USA    Men             25 miles (40.232km)
#   590      Cycling Track  USA    Men               5 miles (8.046km)
#   ...                ...  ...    ...                             ...
#   28686         Lacrosse  USA    Men                        lacrosse
#   28687           Boxing  USA    Men  61.24 - 65.77kg (welterweight)
#   28760         Swimming  GER    Men               400m breaststroke
#   28761         Swimming  GER    Men                 100m backstroke
#   29085  Wrestling Free.  USA    Men   61.23 - 65.77kg (lightweight)
#
#         Event_gender   Medal
#   67               M    Gold
#   119              M  Silver
#   400              M  Silver
#   589              M  Silver
#   590              M  Bronze
#   ...            ...     ...
#   28686            M  Silver
#   28687            M    Gold
#   28760            M    Gold
#   28761            M  Bronze
#   29085            M  Bronze
#
#   [470 rows x 11 columns]),
#  (1908,
#                             Athlete  index    City  Edition      Sport  \
#   114                 ADAM, John M.   1688  London     1908    Sailing
#   142          ADLERSTRAHLE, Märtha   1875  London     1908     Tennis
#   177            AHEARNE, Timoty J.   1282  London     1908  Athletics
#   316    ALEXANDER, Gustav Bernhard   1552  London     1908   Lacrosse
#   317                 ALEXANDER, J.   1553  London     1908   Lacrosse
#   ...                           ...    ...     ...      ...        ...
#   28347       WOODWARD, Vivian John   1381  London     1908   Football
#   28384       WRIGHT, Joseph George   1617  London     1908     Rowing
#   28758                ZACHAR, Imre   1166  London     1908   Aquatics
#   29160              ZULAWSKY, Béla   1347  London     1908    Fencing
#   29195              ZÜRNER, Albert   1138  London     1908   Aquatics
#
#         Discipline  NOC Gender                     Event Event_gender   Medal
#   114      Sailing  GBR    Men                       12m            X  Silver
#   142       Tennis  SWE  Women            singles indoor            W  Bronze
#   177    Athletics  GBR    Men               triple jump            M    Gold
#   316     Lacrosse  GBR    Men                  lacrosse            M  Silver
#   317     Lacrosse  GBR    Men                  lacrosse            M  Silver
#   ...          ...  ...    ...                       ...          ...     ...
#   28347   Football  GBR    Men                  football            M    Gold
#   28384     Rowing  CAN    Men  eight with coxswain (8+)            M  Bronze
#   28758   Swimming  HUN    Men    4x200m freestyle relay            M  Silver
#   29160    Fencing  HUN    Men          sabre individual            M  Silver
#   29195     Diving  GER    Men            3m springboard            M    Gold
#
#   [804 rows x 11 columns]),
#  (1912,
#                       Athlete  index       City  Edition       Sport  \
#   14     AAS, Thomas Valentin   2601  Stockholm     1912     Sailing
#   69             ABERG, Georg   2114  Stockholm     1912   Athletics
#   70             ABERG, Georg   2141  Stockholm     1912   Athletics
#   86         ABRAHAMSEN, Isak   2354  Stockholm     1912  Gymnastics
#   117      ADAMS, Benjamin W.   2107  Stockholm     1912   Athletics
#   ...                     ...    ...        ...      ...         ...
#   28878       ZBORZIL, Arthur   2760  Stockholm     1912      Tennis
#   29118         ZORZI, Angelo   2316  Stockholm     1912  Gymnastics
#   29196        ZÜRNER, Albert   1939  Stockholm     1912    Aquatics
#   29198       ÖRTEGREN, Ruben   2691  Stockholm     1912    Shooting
#   29204       ÖSTENSEN, Östen   2730  Stockholm     1912    Shooting
#
#           Discipline  NOC Gender                       Event Event_gender  \
#   14         Sailing  NOR    Men                          8m            X
#   69       Athletics  SWE    Men                   long jump            M
#   70       Athletics  SWE    Men                 triple jump            M
#   86     Artistic G.  NOR    Men           team, free system            M
#   117      Athletics  USA    Men         high jump, standing            M
#   ...            ...  ...    ...                         ...          ...
#   28878       Tennis  AUT    Men                     doubles            M
#   29118  Artistic G.  ITA    Men            team competition            M
#   29196       Diving  GER    Men                10m platform            M
#   29198     Shooting  SWE    Men  50m small bore rifle, team            M
#   29204     Shooting  NOR    Men            free rifle, team            M
#
#           Medal
#   14       Gold
#   69     Bronze
#   70     Silver
#   86       Gold
#   117    Silver
#   ...       ...
#   28878  Silver
#   29118    Gold
#   29196  Silver
#   29198  Silver
#   29204  Silver
#
#   [885 rows x 11 columns]),
#  (1920,
#                            Athlete  index     City  Edition       Sport  \
#   1          AALTONEN, Arvo Ossian   2849  Antwerp     1920    Aquatics
#   2          AALTONEN, Arvo Ossian   2852  Antwerp     1920    Aquatics
#   9               AANING, Alf Lied   3436  Antwerp     1920  Gymnastics
#   13                 AAS, Karl Jan   3437  Antwerp     1920  Gymnastics
#   62                    ABEL, Sten   3788  Antwerp     1920     Sailing
#   ...                          ...    ...      ...      ...         ...
#   29206            ÖSTENSEN, Östen   4009  Antwerp     1920    Shooting
#   29207          ÖSTERVOLD, Henrik   3737  Antwerp     1920     Sailing
#   29208       ÖSTERVOLD, Jan Olsen   3738  Antwerp     1920     Sailing
#   29209  ÖSTERVOLD, Kristian Olsen   3739  Antwerp     1920     Sailing
#   29210       ÖSTERVOLD, Ole Olsen   3740  Antwerp     1920     Sailing
#
#           Discipline  NOC Gender              Event Event_gender   Medal
#   1         Swimming  FIN    Men  200m breaststroke            M  Bronze
#   2         Swimming  FIN    Men  400m breaststroke            M  Bronze
#   9      Artistic G.  NOR    Men  team, free system            M  Silver
#   13     Artistic G.  NOR    Men  team, free system            M  Silver
#   62         Sailing  NOR    Men                 7m            X  Silver
#   ...            ...  ...    ...                ...          ...     ...
#   29206     Shooting  NOR    Men   free rifle, team            M  Silver
#   29207      Sailing  NOR    Men  12m (rating 1907)            X    Gold
#   29208      Sailing  NOR    Men  12m (rating 1907)            X    Gold
#   29209      Sailing  NOR    Men  12m (rating 1907)            X    Gold
#   29210      Sailing  NOR    Men  12m (rating 1907)            X    Gold
#
#   [1298 rows x 11 columns]),
#  (1924,
#                       Athlete  index   City  Edition          Sport  \
#   60            ABEGGLEN, Max   4564  Paris     1924       Football
#   81              ABRAHAM, F.   4782  Paris     1924          Rugby
#   84         ABRAHAMS, Harold   4236  Paris     1924      Athletics
#   85         ABRAHAMS, Harold   4281  Paris     1924      Athletics
#   181         AHLFORS, Anselm   4988  Paris     1924      Wrestling
#   ...                     ...    ...    ...      ...            ...
#   28837        ZANDER, Robert   4541  Paris     1924       Football
#   29046   ZIBECHI, Alfredo J.   4562  Paris     1924       Football
#   29080           ZINGONE, P.   4563  Paris     1924       Football
#   29144  ZUCCHETTI, Francesco   4412  Paris     1924        Cycling
#   29178        ZWERINA, Anton   4958  Paris     1924  Weightlifting
#
#               Discipline  NOC Gender  \
#   60            Football  SUI    Men
#   81               Rugby  FRA    Men
#   84           Athletics  GBR    Men
#   85           Athletics  GBR    Men
#   181    Wrestling Gre-R  FIN    Men
#   ...                ...  ...    ...
#   28837         Football  SWE    Men
#   29046         Football  URU    Men
#   29080         Football  URU    Men
#   29144    Cycling Track  ITA    Men
#   29178    Weightlifting  AUT    Men
#
#                                                     Event Event_gender   Medal
#   60                                             football            M  Silver
#   81                                                rugby            M  Silver
#   84                                                 100m            M    Gold
#   85                                         4x100m relay            M  Silver
#   181                               - 58kg (bantamweight)            M  Silver
#   ...                                                 ...          ...     ...
#   28837                                          football            M  Bronze
#   29046                                          football            M    Gold
#   29080                                          football            M    Gold
#   29144                              Team Pursuit (4000m)            M    Gold
#   29178  60 - 67.5kg, one-two hand 5 events (lightweight)            M  Silver
#
#   [884 rows x 11 columns]),
#  (1928,
#                           Athlete  index       City  Edition       Sport  \
#   170         AGSTERIBBE, Estella   5463  Amsterdam     1928  Gymnastics
#   293    ALDERMAN, Frederick Pitt   5146  Amsterdam     1928   Athletics
#   357        ALLEN, Richard James   5512  Amsterdam     1928      Hockey
#   409                  AMANN, Max   5076  Amsterdam     1928    Aquatics
#   430          AMBROSETTI, Bianca   5475  Amsterdam     1928  Gymnastics
#   ...                         ...    ...        ...      ...         ...
#   28738      YUSUF, Sayed Mohamed   5526  Amsterdam     1928      Hockey
#   28751          ZABIELSKI, Jerzy   5333  Amsterdam     1928     Fencing
#   28833             ZANDER, Erich   5511  Amsterdam     1928      Hockey
#   29115      ZORRILLA, Victoriano   5038  Amsterdam     1928    Aquatics
#   29164            ZUMELZU, A. B.   5411  Amsterdam     1928    Football
#
#           Discipline  NOC Gender             Event Event_gender   Medal
#   170    Artistic G.  NED  Women  team competition            W    Gold
#   293      Athletics  USA    Men      4x400m relay            M    Gold
#   357         Hockey  IND    Men            hockey            M    Gold
#   409     Water polo  GER    Men        water polo            M    Gold
#   430    Artistic G.  ITA  Women  team competition            W  Silver
#   ...            ...  ...    ...               ...          ...     ...
#   28738       Hockey  IND    Men            hockey            M    Gold
#   28751      Fencing  POL    Men        sabre team            M  Bronze
#   28833       Hockey  GER    Men            hockey            M  Bronze
#   29115     Swimming  ARG    Men    400m freestyle            M    Gold
#   29164     Football  ARG    Men          football            M  Silver
#
#   [710 rows x 11 columns]),
#  (1932,
#                         Athlete  index         City  Edition      Sport  \
#   76      ABLOWICH, Edgar Allen   5857  Los Angeles     1932  Athletics
#   166           AGOSTONI, Carlo   6015  Los Angeles     1932    Fencing
#   167           AGOSTONI, Carlo   6000  Los Angeles     1932    Fencing
#   180    AHLBERG, Bruno Valfrid   5931  Los Angeles     1932     Boxing
#   185           AHLQVIST, Thure   5930  Los Angeles     1932     Boxing
#   ...                       ...    ...          ...      ...        ...
#   28733          YUSA, Masanori   5772  Los Angeles     1932   Aquatics
#   28740     ZABALA, Juan Carlos   5905  Los Angeles     1932  Athletics
#   28858  ZAREMBA, Peter Timothy   5886  Los Angeles     1932  Athletics
#   29057         ZIGLARSKI, Hans   5924  Los Angeles     1932     Boxing
#   29109           ZOMBORI, Ödön   6289  Los Angeles     1932  Wrestling
#
#               Discipline  NOC Gender                           Event  \
#   76           Athletics  USA    Men                    4x400m relay
#   166            Fencing  ITA    Men                       épée team
#   167            Fencing  ITA    Men                 épée individual
#   180             Boxing  FIN    Men  61.24 - 66.68kg (welterweight)
#   185             Boxing  SWE    Men   57.15 - 61.24kg (lightweight)
#   ...                ...  ...    ...                             ...
#   28733         Swimming  JPN    Men          4x200m freestyle relay
#   28740        Athletics  ARG    Men                        marathon
#   28858        Athletics  USA    Men                    hammer throw
#   29057           Boxing  GER    Men      50.8 - 54kg (bantamweight)
#   29109  Wrestling Free.  HUN    Men           - 56kg (bantamweight)
#
#         Event_gender   Medal
#   76               M    Gold
#   166              M  Silver
#   167              M  Bronze
#   180              M  Bronze
#   185              M  Silver
#   ...            ...     ...
#   28733            M    Gold
#   28740            M    Gold
#   28858            M  Bronze
#   29057            M  Silver
#   29109            M  Silver
#
#   [615 rows x 11 columns]),
#  (1936,
#                      Athlete  index    City  Edition              Sport  \
#   27      ABAY-NEMES, Oszkar   6380  Berlin     1936           Aquatics
#   28           ABBA, Silvano   7003  Berlin     1936  Modern Pentathlon
#   112    ADAM, Gordon Belgum   7039  Berlin     1936             Rowing
#   115             ADAM, Otto   6739  Berlin     1936            Fencing
#   125       ADAMSKI, Herbert   7087  Berlin     1936             Rowing
#   ...                    ...    ...     ...      ...                ...
#   28734       YUSA, Masanori   6349  Berlin     1936           Aquatics
#   28735       YUSA, Masanori   6387  Berlin     1936           Aquatics
#   28832        ZANDER, Erich   7002  Berlin     1936             Hockey
#   28887     ZEHETNER, Johann   6949  Berlin     1936           Handball
#   29108        ZOMBORI, Ödön   7163  Berlin     1936          Wrestling
#
#               Discipline  NOC Gender                                Event  \
#   27            Swimming  HUN    Men               4x200m freestyle relay
#   28     Modern Pentath.  ITA    Men               Individual competition
#   112             Rowing  USA    Men             eight with coxswain (8+)
#   115            Fencing  GER    Men                            foil team
#   125             Rowing  GER    Men  pair-oared shell with coxswain (2+)
#   ...                ...  ...    ...                                  ...
#   28734         Swimming  JPN    Men                       100m freestyle
#   28735         Swimming  JPN    Men               4x200m freestyle relay
#   28832           Hockey  GER    Men                               hockey
#   28887         Handball  AUT    Men                             handball
#   29108  Wrestling Free.  HUN    Men                - 56kg (bantamweight)
#
#         Event_gender   Medal
#   27               M  Bronze
#   28               M  Bronze
#   112              M    Gold
#   115              M  Bronze
#   125              M    Gold
#   ...            ...     ...
#   28734            M  Silver
#   28735            M    Gold
#   28832            M  Silver
#   28887            M  Silver
#   29108            M    Gold
#
#   [875 rows x 11 columns]),
#  (1948,
#                            Athlete  index    City  Edition       Sport  \
#   3       AALTONEN, Paavo Johannes   7773  London     1948  Gymnastics
#   4       AALTONEN, Paavo Johannes   7730  London     1948  Gymnastics
#   6       AALTONEN, Paavo Johannes   7709  London     1948  Gymnastics
#   7       AALTONEN, Paavo Johannes   7716  London     1948  Gymnastics
#   116                 ADAM, Pierre   7552  London     1948     Cycling
#   ...                          ...    ...     ...      ...         ...
#   28868              ZATOPEK, Emil   7296  London     1948   Athletics
#   29071  ZIMMERMAN, Suzanne Winona   7221  London     1948    Aquatics
#   29077            ZIMONYI, Robert   7889  London     1948      Rowing
#   29130          ZSITNIK SR., Bela   7890  London     1948      Rowing
#   29152       ZUDDAS, Gianbattista   7469  London     1948      Boxing
#
#             Discipline  NOC Gender                                Event  \
#   3        Artistic G.  FIN    Men                                vault
#   4        Artistic G.  FIN    Men                     team competition
#   6        Artistic G.  FIN    Men                 individual all-round
#   7        Artistic G.  FIN    Men                         pommel horse
#   116    Cycling Track  FRA    Men                 Team Pursuit (4000m)
#   ...              ...  ...    ...                                  ...
#   28868      Athletics  TCH    Men                               10000m
#   29071       Swimming  USA  Women                      100m backstroke
#   29077         Rowing  HUN    Men  pair-oared shell with coxswain (2+)
#   29130         Rowing  HUN    Men  pair-oared shell with coxswain (2+)
#   29152         Boxing  ITA    Men             51 - 54kg (bantamweight)
#
#         Event_gender   Medal
#   3                M    Gold
#   4                M    Gold
#   6                M  Bronze
#   7                M    Gold
#   116              M    Gold
#   ...            ...     ...
#   28868            M    Gold
#   29071            W  Silver
#   29077            M  Bronze
#   29130            M  Bronze
#   29152            M  Silver
#
#   [814 rows x 11 columns]),
#  (1952,
#                           Athlete  index      City  Edition          Sport  \
#   5      AALTONEN, Paavo Johannes   8563  Helsinki     1952     Gymnastics
#   109       ACOSTA Y LARA, Martin   8240  Helsinki     1952     Basketball
#   134             ADKINS, Charles   8302  Helsinki     1952         Boxing
#   186         AHLUND, Olof "Olle"   8497  Helsinki     1952       Football
#   241            AKERLUND, Gunnar   8351  Helsinki     1952  Canoe / Kayak
#   ...                         ...    ...       ...      ...            ...
#   29001            ZHILIN, Georgi   8706  Helsinki     1952         Rowing
#   29047      ZIEGLER, Edwin (Edy)   8359  Helsinki     1952        Cycling
#   29146      ZUCCONELLI, Vincenzo   8370  Helsinki     1952        Cycling
#   29188            ZYBINA, Galina   8235  Helsinki     1952      Athletics
#   29215         ÖSTRAND, Per-Olof   8051  Helsinki     1952       Aquatics
#
#               Discipline  NOC Gender                             Event  \
#   5          Artistic G.  FIN    Men                  team competition
#   109         Basketball  URU    Men                        basketball
#   134             Boxing  USA    Men  60 - 63.5kg (light-welterweight)
#   186           Football  SWE    Men                          football
#   241    Canoe / Kayak F  SWE    Men                        K-2 10000m
#   ...                ...  ...    ...                               ...
#   29001           Rowing  URS    Men                double sculls (2x)
#   29047     Cycling Road  GER    Men              individual road race
#   29146     Cycling Road  ITA    Men                   team time trial
#   29188        Athletics  URS  Women                          shot put
#   29215         Swimming  SWE    Men                    400m freestyle
#
#         Event_gender   Medal
#   5                M  Bronze
#   109              M  Bronze
#   134              M    Gold
#   186              M  Bronze
#   241              M  Silver
#   ...            ...     ...
#   29001            M  Silver
#   29047            M  Bronze
#   29146            M  Silver
#   29188            W    Gold
#   29215            M  Bronze
#
#   [889 rows x 11 columns]),
#  (1956,
#                    Athlete  index                   City  Edition  \
#   45          ABDUL, Hamid   9564  Melbourne / Stockholm     1956
#   72      ABERNETHY, Moira   8952  Melbourne / Stockholm     1956
#   154               AFRIKA   9293  Melbourne / Stockholm     1956
#   161        AGEEV, Viktor   8976  Melbourne / Stockholm     1956
#   179      AHKTAR, Hussain   9565  Melbourne / Stockholm     1956
#   ...                  ...    ...                    ...      ...
#   29051  ZIELINSKI, Marian   9729  Melbourne / Stockholm     1956
#   29135       ZUB, Ryszard   9389  Melbourne / Stockholm     1956
#   29143     ZUBKOV, Viktor   9167  Melbourne / Stockholm     1956
#   29169      ZUZEJ, Marjan   9004  Melbourne / Stockholm     1956
#   29187     ZYBINA, Galina   9128  Melbourne / Stockholm     1956
#
#                  Sport     Discipline  NOC Gender  \
#   45            Hockey         Hockey  PAK    Men
#   72          Aquatics       Swimming  RSA  Women
#   154       Equestrian       Dressage  EUA  Women
#   161         Aquatics     Water polo  URS    Men
#   179           Hockey         Hockey  PAK    Men
#   ...              ...            ...  ...    ...
#   29051  Weightlifting  Weightlifting  POL    Men
#   29135        Fencing        Fencing  POL    Men
#   29143     Basketball     Basketball  URS    Men
#   29169       Aquatics     Water polo  YUG    Men
#   29187      Athletics      Athletics  URS  Women
#
#                                     Event Event_gender   Medal
#   45                               hockey            M  Silver
#   72               4x100m freestyle relay            W  Bronze
#   154                                team            X  Silver
#   161                          water polo            M  Bronze
#   179                              hockey            M  Silver
#   ...                                 ...          ...     ...
#   29051  56 - 60kg, total (featherweight)            M  Bronze
#   29135                        sabre team            M  Silver
#   29143                        basketball            M  Silver
#   29169                        water polo            M  Silver
#   29187                          shot put            W  Silver
#
#   [885 rows x 11 columns]),
#  (1960,
#                   Athlete  index  City  Edition       Sport    Discipline  NOC  \
#   46         ABDUL, Hamid  10438  Rome     1960      Hockey        Hockey  PAK
#   47      ABDUL, Rashid I  10439  Rome     1960      Hockey        Hockey  PAK
#   52        ABDUL, Waheed  10440  Rome     1960      Hockey        Hockey  PAK
#   126      ADAMSKI, Jerzy  10100  Rome     1960      Boxing        Boxing  POL
#   138         ADLER, Egon  10175  Rome     1960     Cycling  Cycling Road  EUA
#   ...                 ...    ...   ...      ...         ...           ...  ...
#   29133  ZSIVOTZKY, Gyula  10015  Rome     1960   Athletics     Athletics  HUN
#   29137      ZUB, Ryszard  10305  Rome     1960     Fencing       Fencing  POL
#   29142    ZUBKOV, Viktor  10084  Rome     1960  Basketball    Basketball  URS
#   29145  ZUCCHI, Giovanni  10531  Rome     1960      Rowing        Rowing  ITA
#   29192  ZÄHRINGER, Klaus  10596  Rome     1960    Shooting      Shooting  EUA
#
#         Gender                                Event Event_gender   Medal
#   46       Men                               hockey            M    Gold
#   47       Men                               hockey            M    Gold
#   52       Men                               hockey            M    Gold
#   126      Men            54 - 57kg (featherweight)            M  Silver
#   138      Men                      team time trial            M  Silver
#   ...      ...                                  ...          ...     ...
#   29133    Men                         hammer throw            M  Silver
#   29137    Men                           sabre team            M  Silver
#   29142    Men                           basketball            M  Silver
#   29145    Men  four-oared shell with coxswain (4-)            M  Bronze
#   29192    Men   50m rifle 3 positions (3x40 shots)            M  Bronze
#
#   [882 rows x 11 columns]),
#  (1964,
#                           Athlete  index   City  Edition       Sport  \
#   44                 ABDUL, Hamid  11370  Tokyo     1964      Hockey
#   89              ABRAMOVA, Nelli  11603  Tokyo     1964  Volleyball
#   94         ABUKAWA-CHIBA, Ginko  11314  Tokyo     1964  Gymnastics
#   151               AEFFKE, Klaus  11444  Tokyo     1964      Rowing
#   162               AGEEV, Viktor  10785  Tokyo     1964    Aquatics
#   ...                         ...    ...    ...      ...         ...
#   29078           ZIMONYI, Robert  11443  Tokyo     1964      Rowing
#   29105  ZOET, Hubertus Balthazar  11079  Tokyo     1964     Cycling
#   29131          ZSIVOTZKY, Gyula  10917  Tokyo     1964   Athletics
#   29136              ZUB, Ryszard  11207  Tokyo     1964     Fencing
#   29186            ZYBINA, Galina  10948  Tokyo     1964   Athletics
#
#            Discipline  NOC Gender                     Event Event_gender   Medal
#   44           Hockey  PAK    Men                    hockey            M  Silver
#   89       Volleyball  URS  Women                volleyball            W  Silver
#   94      Artistic G.  JPN  Women          team competition            W  Bronze
#   151          Rowing  EUA    Men  eight with coxswain (8+)            M  Silver
#   162      Water polo  URS    Men                water polo            M  Bronze
#   ...             ...  ...    ...                       ...          ...     ...
#   29078        Rowing  USA    Men  eight with coxswain (8+)            M    Gold
#   29105  Cycling Road  NED    Men           team time trial            M    Gold
#   29131     Athletics  HUN    Men              hammer throw            M  Silver
#   29136       Fencing  POL    Men                sabre team            M  Bronze
#   29186     Athletics  URS  Women                  shot put            W  Bronze
#
#   [1010 rows x 11 columns]),
#  (1968,
#                          Athlete  index    City  Edition       Sport  \
#   48           ABDUL, Rashid III  12403  Mexico     1968      Hockey
#   219    AISHER, Robin Allingham  12520  Mexico     1968     Sailing
#   269           ALBARELLI, Fabio  12544  Mexico     1968     Sailing
#   279             ALBINI, Abramo  12481  Mexico     1968      Rowing
#   368    ALLHUSEN, Derek Swithin  12171  Mexico     1968  Equestrian
#   ...                        ...    ...     ...      ...         ...
#   29111            ZORGA, Aljosa  12031  Mexico     1968  Basketball
#   29114            ZORN, Zachary  11772  Mexico     1968    Aquatics
#   29132         ZSIVOTZKY, Gyula  11958  Mexico     1968   Athletics
#   29147           ZUCHOLD, Erika  12366  Mexico     1968  Gymnastics
#   29148           ZUCHOLD, Erika  12387  Mexico     1968  Gymnastics
#
#           Discipline  NOC Gender                        Event Event_gender  \
#   48          Hockey  PAK    Men                       hockey            M
#   219        Sailing  GBR    Men                         5.5m            X
#   269        Sailing  ITA    Men  single-handed dinghy (Finn)            M
#   279         Rowing  ITA    Men   four without coxswain (4-)            M
#   368       Eventing  GBR    Men                   individual            X
#   ...            ...  ...    ...                          ...          ...
#   29111   Basketball  YUG    Men                   basketball            M
#   29114     Swimming  USA    Men       4x100m freestyle relay            M
#   29132    Athletics  HUN    Men                 hammer throw            M
#   29147  Artistic G.  GDR  Women             team competition            W
#   29148  Artistic G.  GDR  Women                        vault            W
#
#           Medal
#   48       Gold
#   219    Bronze
#   269    Bronze
#   279    Bronze
#   368    Silver
#   ...       ...
#   29111  Silver
#   29114    Gold
#   29132    Gold
#   29147  Bronze
#   29148  Silver
#
#   [1031 rows x 11 columns]),
#  (1972,
#                      Athlete  index    City  Edition       Sport  \
#   49       ABDUL, Rashid III  13551  Munich     1972      Hockey
#   53     ABDULBEKOV, Zagalav  13853  Munich     1972   Wrestling
#   61             ABEL, Irene  13459  Munich     1972  Gymnastics
#   77         ABOIMOV, Viktor  12804  Munich     1972    Aquatics
#   239           AKDAG, Vehbi  13854  Munich     1972   Wrestling
#   ...                    ...    ...     ...      ...         ...
#   29089      ZIVKOVIC, Zoran  13501  Munich     1972    Handball
#   29113        ZORKO, Zdenko  13502  Munich     1972    Handball
#   29149       ZUCHOLD, Erika  13464  Munich     1972  Gymnastics
#   29150       ZUCHOLD, Erika  13467  Munich     1972  Gymnastics
#   29151       ZUCHOLD, Erika  13473  Munich     1972  Gymnastics
#
#               Discipline  NOC Gender                      Event Event_gender  \
#   49              Hockey  PAK    Men                     hockey            M
#   53     Wrestling Free.  URS    Men  57 - 62kg (featherweight)            M
#   61         Artistic G.  GDR  Women           team competition            W
#   77            Swimming  URS    Men     4x100m freestyle relay            M
#   239    Wrestling Free.  TUR    Men  57 - 62kg (featherweight)            M
#   ...                ...  ...    ...                        ...          ...
#   29089         Handball  YUG    Men                   handball            M
#   29113         Handball  YUG    Men                   handball            M
#   29149      Artistic G.  GDR  Women           team competition            W
#   29150      Artistic G.  GDR  Women                uneven bars            W
#   29151      Artistic G.  GDR  Women                      vault            W
#
#           Medal
#   49     Silver
#   53       Gold
#   61     Silver
#   77     Silver
#   239    Silver
#   ...       ...
#   29089    Gold
#   29113    Gold
#   29149  Silver
#   29150  Silver
#   29151  Silver
#
#   [1185 rows x 11 columns]),
#  (1976,
#                        Athlete  index      City  Edition              Sport  \
#   50         ABDUL, Rashid III  14743  Montreal     1976             Hockey
#   106           ACKERLEY, Paul  14759  Montreal     1976             Hockey
#   113               ADAM, Jiri  14824  Montreal     1976  Modern Pentathlon
#   153     AFRASILOAIA, Felicia  14956  Montreal     1976             Rowing
#   196      AHRENHOLZ, Brigitte  14881  Montreal     1976             Rowing
#   ...                      ...    ...       ...      ...                ...
#   29100      ZOBELT, Roswietha  14965  Montreal     1976             Rowing
#   29103       ZOBER, Hannelore  14742  Montreal     1976           Handball
#   29104  ZOCH, Jacqueline Jean  14880  Montreal     1976             Rowing
#   29141           ZUBKO, Elena  14898  Montreal     1976             Rowing
#   29176    ZVYAGINTSEV, Viktor  14550  Montreal     1976           Football
#
#               Discipline  NOC Gender                                Event  \
#   50              Hockey  PAK    Men                               hockey
#   106             Hockey  NZL    Men                               hockey
#   113    Modern Pentath.  TCH    Men                     Team competition
#   153             Rowing  ROU  Women  quadruple sculls with coxswain (4x)
#   196             Rowing  GDR  Women             eight with coxswain (8+)
#   ...                ...  ...    ...                                  ...
#   29100           Rowing  GDR  Women  quadruple sculls with coxswain (4x)
#   29103         Handball  GDR  Women                             handball
#   29104           Rowing  USA  Women             eight with coxswain (8+)
#   29141           Rowing  URS  Women             eight with coxswain (8+)
#   29176         Football  URS    Men                             football
#
#         Event_gender   Medal
#   50               M  Bronze
#   106              M    Gold
#   113              M  Silver
#   153              W  Bronze
#   196              W    Gold
#   ...            ...     ...
#   29100            W    Gold
#   29103            W  Silver
#   29104            W  Bronze
#   29141            W  Silver
#   29176            M  Bronze
#
#   [1305 rows x 11 columns]),
#  (1980,
#                            Athlete  index    City  Edition      Sport  \
#   22     ABASCAL GARCIA, Alejandro  16390  Moscow     1980    Sailing
#   75                ABILOV, Ismail  16554  Moscow     1980  Wrestling
#   82                 ABRAHAM, Gary  15292  Moscow     1980   Aquatics
#   91            ABSAIDOV, Saipulla  16548  Moscow     1980  Wrestling
#   95      ABUSHAKHMETOV, Aleksandr  15794  Moscow     1980    Fencing
#   ...                          ...    ...     ...      ...        ...
#   29162             ZULIANI, Mauro  15439  Moscow     1980  Athletics
#   29163      ZUMALACARREGUI, Jaime  16118  Moscow     1980     Hockey
#   29183       ZWOLINSKI, Krzysztof  15423  Moscow     1980  Athletics
#   29189             ZYCH, Boguslaw  15817  Moscow     1980    Fencing
#   29197        ÖRSTED, Hans-Henrik  15711  Moscow     1980    Cycling
#
#               Discipline  NOC Gender                     Event Event_gender  \
#   22             Sailing  ESP    Men           flying dutchman            X
#   75     Wrestling Free.  BUL    Men  74 - 82kg (middleweight)            M
#   82            Swimming  GBR    Men       4x100m medley relay            M
#   91     Wrestling Free.  URS    Men   62 - 68kg (lightweight)            M
#   95             Fencing  URS    Men                 épée team            M
#   ...                ...  ...    ...                       ...          ...
#   29162        Athletics  ITA    Men              4x400m relay            M
#   29163           Hockey  ESP    Men                    hockey            M
#   29183        Athletics  POL    Men              4x100m relay            M
#   29189          Fencing  POL    Men                 foil team            M
#   29197    Cycling Track  DEN    Men        Individual Pursuit            M
#
#           Medal
#   22       Gold
#   75       Gold
#   82     Bronze
#   91       Gold
#   95     Bronze
#   ...       ...
#   29162  Bronze
#   29163  Silver
#   29183  Silver
#   29189  Bronze
#   29197  Bronze
#
#   [1387 rows x 11 columns]),
#  (1984,
#                             Athlete  index         City  Edition       Sport  \
#   23     ABASCAL GOMEZ, Jose Manuel  16806  Los Angeles     1984   Athletics
#   32             ABBAGNALE, Carmine  17778  Los Angeles     1984      Rowing
#   37            ABBAGNALE, Giuseppe  17779  Los Angeles     1984      Rowing
#   42                    ABDO, Reema  16709  Los Angeles     1984    Aquatics
#   51               ABDUL, Rashid IV  17531  Los Angeles     1984      Hockey
#   ...                           ...    ...          ...      ...         ...
#   29079              ZINDLER, Petra  16670  Los Angeles     1984    Aquatics
#   29090                ZIZIC, Rajko  16961  Los Angeles     1984  Basketball
#   29112             ZORKIC, Nebojsa  16962  Los Angeles     1984  Basketball
#   29124              ZOVKO, Zdravko  17458  Los Angeles     1984    Handball
#   29128              ZSCHERPE, Iris  16688  Los Angeles     1984    Aquatics
#
#          Discipline  NOC Gender                                Event  \
#   23      Athletics  ESP    Men                                1500m
#   32         Rowing  ITA    Men  pair-oared shell with coxswain (2+)
#   37         Rowing  ITA    Men  pair-oared shell with coxswain (2+)
#   42       Swimming  CAN  Women                  4x100m medley relay
#   51         Hockey  PAK    Men                               hockey
#   ...           ...  ...    ...                                  ...
#   29079    Swimming  FRG  Women               400m individual medley
#   29090  Basketball  YUG    Men                           basketball
#   29112  Basketball  YUG    Men                           basketball
#   29124    Handball  YUG    Men                             handball
#   29128    Swimming  FRG  Women               4x100m freestyle relay
#
#         Event_gender   Medal
#   23               M  Bronze
#   32               M    Gold
#   37               M    Gold
#   42               W  Bronze
#   51               M    Gold
#   ...            ...     ...
#   29079            W  Bronze
#   29090            M  Bronze
#   29112            M  Bronze
#   29124            M    Gold
#   29128            W  Bronze
#
#   [1459 rows x 11 columns]),
#  (1988,
#                         Athlete  index   City  Edition          Sport  \
#   10      AARDENBURG, Willemien  19062  Seoul     1988         Hockey
#   30        ABBAGNALE, Agostino  19283  Seoul     1988         Rowing
#   33         ABBAGNALE, Carmine  19273  Seoul     1988         Rowing
#   35        ABBAGNALE, Giuseppe  19274  Seoul     1988         Rowing
#   78            ABRAHAM, Attila  18609  Seoul     1988  Canoe / Kayak
#   ...                       ...    ...    ...      ...            ...
#   29070        ZILPORYTE, Laima  18632  Seoul     1988        Cycling
#   29074     ZIMMERMANN, Kathrin  18095  Seoul     1988       Aquatics
#   29161  ZULIANELLO, Claudio F.  19446  Seoul     1988     Volleyball
#   29193         ZÜHLKE, Steffen  19282  Seoul     1988         Rowing
#   29194          ZÜLOW, Andreas  18534  Seoul     1988         Boxing
#
#               Discipline  NOC Gender                                   Event  \
#   10              Hockey  NED  Women                                  hockey
#   30              Rowing  ITA    Men  quadruple sculls without coxswain (4x)
#   33              Rowing  ITA    Men     pair-oared shell with coxswain (2+)
#   35              Rowing  ITA    Men     pair-oared shell with coxswain (2+)
#   78     Canoe / Kayak F  HUN    Men                  K-4 1000m (kayak four)
#   ...                ...  ...    ...                                     ...
#   29070     Cycling Road  URS  Women                    individual road race
#   29074         Swimming  GDR  Women                         200m backstroke
#   29161       Volleyball  ARG    Men                              volleyball
#   29193           Rowing  GDR    Men  quadruple sculls without coxswain (4x)
#   29194           Boxing  GDR    Men                 57 - 60kg (lightweight)
#
#         Event_gender   Medal
#   10               W  Bronze
#   30               M    Gold
#   33               M    Gold
#   35               M    Gold
#   78               M    Gold
#   ...            ...     ...
#   29070            W  Bronze
#   29074            W  Silver
#   29161            M  Bronze
#   29193            M  Bronze
#   29194            M    Gold
#
#   [1546 rows x 11 columns]),
#  (1992,
#                      Athlete  index       City  Edition       Sport  Discipline  \
#   26             ABAY, Peter  20477  Barcelona     1992     Fencing     Fencing
#   34      ABBAGNALE, Carmine  20970  Barcelona     1992      Rowing      Rowing
#   36     ABBAGNALE, Giuseppe  20971  Barcelona     1992      Rowing      Rowing
#   58      ABDUVALIEV, Andrey  19984  Barcelona     1992   Athletics   Athletics
#   59            ABEBE, Addis  19849  Barcelona     1992   Athletics   Athletics
#   ...                    ...    ...        ...      ...         ...         ...
#   29110      ZOODSMA, Ronald  21175  Barcelona     1992  Volleyball  Volleyball
#   29170       ZVEGELJ, Denis  20860  Barcelona     1992      Rowing      Rowing
#   29173     ZVEREVA, Natalya  21128  Barcelona     1992      Tennis      Tennis
#   29180      ZWERVER, Ronald  21176  Barcelona     1992  Volleyball  Volleyball
#   29185  ZWOLLE, Hendrik Jan  20866  Barcelona     1992      Rowing      Rowing
#
#          NOC Gender                                Event Event_gender   Medal
#   26     HUN    Men                           sabre team            M  Silver
#   34     ITA    Men  pair-oared shell with coxswain (2+)            M  Silver
#   36     ITA    Men  pair-oared shell with coxswain (2+)            M  Silver
#   58     EUN    Men                         hammer throw            M    Gold
#   59     ETH    Men                               10000m            M  Bronze
#   ...    ...    ...                                  ...          ...     ...
#   29110  NED    Men                           volleyball            M  Silver
#   29170  SLO    Men                    coxless pair (2-)            M  Bronze
#   29173  EUN  Women                              doubles            W  Bronze
#   29180  NED    Men                           volleyball            M  Silver
#   29185  NED    Men                   double sculls (2x)            M  Bronze
#
#   [1705 rows x 11 columns]),
#  (1996,
#                       Athlete  index     City  Edition       Sport  \
#   11        AARDEWIJN, Pepijn  22769  Atlanta     1996      Rowing
#   12     AARONES, Ann Kristin  22267  Atlanta     1996    Football
#   20       ABARCA, Jose Maria  21538  Atlanta     1996    Aquatics
#   31      ABBAGNALE, Agostino  22677  Atlanta     1996      Rowing
#   54        ABDULLAYEV, Namig  23109  Atlanta     1996   Wrestling
#   ...                     ...    ...      ...      ...         ...
#   29157  ZUKAUSKAS, Mindaugas  21863  Atlanta     1996  Basketball
#   29172       ZVEREVA, Ellina  21720  Atlanta     1996   Athletics
#   29181       ZWERVER, Ronald  23022  Atlanta     1996  Volleyball
#   29182       ZWIERS, Claudia  22643  Atlanta     1996        Judo
#   29184   ZWOLLE, Hendrik Jan  22704  Atlanta     1996      Rowing
#
#               Discipline  NOC Gender                           Event  \
#   11              Rowing  NED    Men  lightweight double sculls (2x)
#   12            Football  NOR  Women                        football
#   20          Water polo  ESP    Men                      water polo
#   31              Rowing  ITA    Men              double sculls (2x)
#   54     Wrestling Free.  AZE    Men           48 - 52kg (flyweight)
#   ...                ...  ...    ...                             ...
#   29157       Basketball  LTU    Men                      basketball
#   29172        Athletics  BLR  Women                    discus throw
#   29181       Volleyball  NED    Men                      volleyball
#   29182             Judo  NED  Women        61 - 66kg (middleweight)
#   29184           Rowing  NED    Men        eight with coxswain (8+)
#
#         Event_gender   Medal
#   11               M  Silver
#   12               W  Bronze
#   20               M    Gold
#   31               M    Gold
#   54               M  Silver
#   ...            ...     ...
#   29157            M  Bronze
#   29172            W  Bronze
#   29181            M    Gold
#   29182            W  Bronze
#   29184            M    Gold
#
#   [1859 rows x 11 columns]),
#  (2000,
#                             Athlete  index    City  Edition       Sport  \
#   19          ABANDA ETONG, Patrice  24202  Sydney     2000    Football
#   29            ABBAGNALE, Agostino  24757  Sydney     2000      Rowing
#   43     ABDOOLLAYEV, Mahammatkodir  23892  Sydney     2000      Boxing
#   55              ABDULLAYEV, Namig  25129  Sydney     2000   Wrestling
#   56           ABDUR-RAHIM, Shareef  23806  Sydney     2000  Basketball
#   ...                           ...    ...     ...      ...         ...
#   29129           ZSEMBERY, Tamasne  24480  Sydney     2000    Handball
#   29154           ZUIJDWEG, Martijn  23342  Sydney     2000    Aquatics
#   29156        ZUKAUSKAS, Eurelijus  23805  Sydney     2000  Basketball
#   29171             ZVEREVA, Ellina  23644  Sydney     2000   Athletics
#   29190              ZYKINA, Olesya  23611  Sydney     2000   Athletics
#
#               Discipline  NOC Gender                                   Event  \
#   19            Football  CMR    Men                                football
#   29              Rowing  ITA    Men  quadruple sculls without coxswain (4x)
#   43              Boxing  UZB    Men        60 - 63.5kg (light-welterweight)
#   55     Wrestling Free.  AZE    Men                               48 - 54kg
#   56          Basketball  USA    Men                              basketball
#   ...                ...  ...    ...                                     ...
#   29129         Handball  HUN  Women                                handball
#   29154         Swimming  NED    Men                  4x200m freestyle relay
#   29156       Basketball  LTU    Men                              basketball
#   29171        Athletics  BLR  Women                            discus throw
#   29190        Athletics  RUS  Women                            4x400m relay
#
#         Event_gender   Medal
#   19               M    Gold
#   29               M    Gold
#   43               M    Gold
#   55               M    Gold
#   56               M    Gold
#   ...            ...     ...
#   29129            W  Silver
#   29154            M  Bronze
#   29156            M  Bronze
#   29171            W    Gold
#   29190            W  Bronze
#
#   [2015 rows x 11 columns]),
#  (2004,
#                      Athlete  index    City  Edition       Sport  \
#   21           ABAS, Stephen  27125  Athens     2004   Wrestling
#   24       ABASSOVA, Tamilla  26049  Athens     2004     Cycling
#   41           ABDALLAH, Nia  26960  Athens     2004   Taekwondo
#   83         ABRAHAMIAN, Ara  27167  Athens     2004   Wrestling
#   88          ABRAMOV, Pavel  27004  Athens     2004  Volleyball
#   ...                    ...    ...     ...      ...         ...
#   29168        ZUYEV, Viktar  25923  Athens     2004      Boxing
#   29174     ZVIADAURI, Zurab  26622  Athens     2004        Judo
#   29177         ZWEHL, Julia  26556  Athens     2004      Hockey
#   29179  ZWERING, Klaas-Erik  25297  Athens     2004    Aquatics
#   29191       ZYKINA, Olesya  25639  Athens     2004   Athletics
#
#               Discipline  NOC Gender                     Event Event_gender  \
#   21     Wrestling Free.  USA    Men                    - 55kg            M
#   24       Cycling Track  RUS  Women                    sprint            W
#   41           Taekwondo  USA  Women                49 - 57 kg            W
#   83     Wrestling Gre-R  SWE    Men                 74 - 84kg            M
#   88          Volleyball  RUS    Men                volleyball            M
#   ...                ...  ...    ...                       ...          ...
#   29168           Boxing  BLR    Men   81 - 91kg (heavyweight)            M
#   29174             Judo  GEO    Men  81 - 90kg (middleweight)            M
#   29177           Hockey  GER  Women                    hockey            W
#   29179         Swimming  NED    Men    4x100m freestyle relay            M
#   29191        Athletics  RUS  Women              4x400m relay            W
#
#           Medal
#   21     Silver
#   24     Silver
#   41     Silver
#   83     Silver
#   88     Bronze
#   ...       ...
#   29168  Silver
#   29174    Gold
#   29177    Gold
#   29179  Silver
#   29191  Silver
#
#   [1998 rows x 11 columns]),
#  (2008,
#                                 Athlete  index     City  Edition          Sport  \
#   8                    AAMODT, Ragnhild  28460  Beijing     2008       Handball
#   15                   ABAJO, Jose Luis  28134  Beijing     2008        Fencing
#   16                   ABAKUMOVA, Maria  27691  Beijing     2008      Athletics
#   17                ABALMASAU, Aliaksei  27983  Beijing     2008  Canoe / Kayak
#   18                         ABALO, Luc  28417  Beijing     2008       Handball
#   ...                               ...    ...      ...      ...            ...
#   29134  ZU-SAYN WITTGENSTEIN, Nathalie  28095  Beijing     2008     Equestrian
#   29139                  ZUBARI, Shahar  28819  Beijing     2008        Sailing
#   29140                 ZUBCIC, Martina  28977  Beijing     2008      Taekwondo
#   29153                  ZUEVA, Natalia  28387  Beijing     2008     Gymnastics
#   29175                 ZVONAREVA, Vera  29007  Beijing     2008         Tennis
#
#               Discipline  NOC Gender                   Event Event_gender  \
#   8             Handball  NOR  Women                handball            W
#   15             Fencing  ESP    Men         épée individual            M
#   16           Athletics  RUS  Women           javelin throw            W
#   17     Canoe / Kayak F  BLR    Men  K-4 1000m (kayak four)            M
#   18            Handball  FRA    Men                handball            M
#   ...                ...  ...    ...                     ...          ...
#   29134         Dressage  DEN  Women                    team            X
#   29139          Sailing  ISR    Men       RS:X - Windsurfer            M
#   29140        Taekwondo  CRO  Women              49 - 57 kg            W
#   29153      Rhythmic G.  RUS  Women       group competition            W
#   29175           Tennis  RUS  Women                 singles            W
#
#           Medal
#   8        Gold
#   15     Bronze
#   16     Silver
#   17       Gold
#   18       Gold
#   ...       ...
#   29134  Bronze
#   29139  Bronze
#   29140  Bronze
#   29153    Gold
#   29175  Bronze
#
#   [2042 rows x 11 columns])]

# %%
for group_key, group_value in oo.groupby('Edition'):
# Out:
#   File "/var/folders/mg/lv8dqt5s7lq185cs_fdqzh1m0000gn/T/ipykernel_70429/1439804722.py", line 1
#     for group_key, group_value in oo.groupby('Edition'):
#                                                          ^
# IndentationError: expected an indented block

# %%
for group_key, group_value in oo.groupby('Edition'): 
    print(group_key)
    print(group_value)
# Out:
# 1896
#                         Athlete  index    City  Edition       Sport  \
# 585            ANDREOU, Joannis      7  Athens     1896    Aquatics
# 596    ANDRIAKOPOULOS, Nicolaos    110  Athens     1896  Gymnastics
# 597    ANDRIAKOPOULOS, Nicolaos     82  Athens     1896  Gymnastics
# 922      ATHANASOPOULOS, Spyros    111  Athens     1896  Gymnastics
# 1466             BATTEL, Edward     48  Athens     1896     Cycling
# ...                         ...    ...     ...      ...         ...
# 28458        XENAKIS, Thomasios     83  Athens     1896  Gymnastics
# 28459        XENAKIS, Thomasios    113  Athens     1896  Gymnastics
# 29165             ZUTTER, Louis     75  Athens     1896  Gymnastics
# 29166             ZUTTER, Louis    116  Athens     1896  Gymnastics
# 29167             ZUTTER, Louis     76  Athens     1896  Gymnastics
#
#          Discipline  NOC Gender                 Event Event_gender   Medal
# 585        Swimming  GRE    Men       1200m freestyle            M  Silver
# 596     Artistic G.  GRE    Men   team, parallel bars            M  Silver
# 597     Artistic G.  GRE    Men         rope climbing            M    Gold
# 922     Artistic G.  GRE    Men   team, parallel bars            M  Silver
# 1466   Cycling Road  GBR    Men  individual road race            M  Bronze
# ...             ...  ...    ...                   ...          ...     ...
# 28458   Artistic G.  GRE    Men         rope climbing            M  Silver
# 28459   Artistic G.  GRE    Men   team, parallel bars            M  Silver
# 29165   Artistic G.  SUI    Men         parallel bars            M  Silver
# 29166   Artistic G.  SUI    Men                 vault            M  Silver
# 29167   Artistic G.  SUI    Men          pommel horse            M    Gold
#
# [151 rows x 11 columns]
# 1900
#                      Athlete  index   City  Edition       Sport  Discipline  \
# 0               AABYE, Edgar    651  Paris     1900  Tug of War  Tug of War
# 39     ABBOTT, Margaret Ives    417  Paris     1900        Golf        Golf
# 66              ABELL, Louis    443  Paris     1900      Rowing      Rowing
# 225         AITOFF, Vladimir    502  Paris     1900       Rugby       Rugby
# 274               ALBERT, A.    503  Paris     1900       Rugby       Rugby
# ...                      ...    ...    ...      ...         ...         ...
# 28883  ZEALLEY, James Edward    399  Paris     1900    Football    Football
# 29211             ÖSTMO, Ole    603  Paris     1900    Shooting    Shooting
# 29212             ÖSTMO, Ole    608  Paris     1900    Shooting    Shooting
# 29213             ÖSTMO, Ole    621  Paris     1900    Shooting    Shooting
# 29214             ÖSTMO, Ole    596  Paris     1900    Shooting    Shooting
#
#        NOC Gender                          Event Event_gender   Medal
# 0      ZZX    Men                     tug of war            M    Gold
# 39     USA  Women                     individual            W    Gold
# 66     USA    Men       eight with coxswain (8+)            M    Gold
# 225    FRA    Men                          rugby            M    Gold
# 274    FRA    Men                          rugby            M    Gold
# ...    ...    ...                            ...          ...     ...
# 28883  GBR    Men                       football            M    Gold
# 29211  NOR    Men        army rifle, 300m, prone            M  Bronze
# 29212  NOR    Men     army rifle, 300m, standing            M  Silver
# 29213  NOR    Men               free rifle, team            M  Silver
# 29214  NOR    Men  army rifle, 300m, 3 positions            M  Bronze
#
# [512 rows x 11 columns]
# 1904
#                   Athlete  index      City  Edition      Sport  \
# 67           ABELL, Louis   1046  St Louis     1904     Rowing
# 119       ADAMS, Edgar H.    669  St Louis     1904   Aquatics
# 400         AMAN, Charles   1072  St Louis     1904     Rowing
# 589    ANDREWS, Arthur F.    854  St Louis     1904    Cycling
# 590    ANDREWS, Arthur F.    855  St Louis     1904    Cycling
# ...                   ...    ...       ...      ...        ...
# 28686               YOUNG   1030  St Louis     1904   Lacrosse
# 28687       YOUNG, Albert    833  St Louis     1904     Boxing
# 28760    ZACHARIAS, Georg    683  St Louis     1904   Aquatics
# 28761    ZACHARIAS, Georg    670  St Louis     1904   Aquatics
# 29085      ZIRKEL, Albert   1127  St Louis     1904  Wrestling
#
#             Discipline  NOC Gender                           Event  \
# 67              Rowing  USA    Men        eight with coxswain (8+)
# 119             Diving  USA    Men             plunge for distance
# 400             Rowing  USA    Men      four without coxswain (4-)
# 589      Cycling Track  USA    Men             25 miles (40.232km)
# 590      Cycling Track  USA    Men               5 miles (8.046km)
# ...                ...  ...    ...                             ...
# 28686         Lacrosse  USA    Men                        lacrosse
# 28687           Boxing  USA    Men  61.24 - 65.77kg (welterweight)
# 28760         Swimming  GER    Men               400m breaststroke
# 28761         Swimming  GER    Men                 100m backstroke
# 29085  Wrestling Free.  USA    Men   61.23 - 65.77kg (lightweight)
#
#       Event_gender   Medal
# 67               M    Gold
# 119              M  Silver
# 400              M  Silver
# 589              M  Silver
# 590              M  Bronze
# ...            ...     ...
# 28686            M  Silver
# 28687            M    Gold
# 28760            M    Gold
# 28761            M  Bronze
# 29085            M  Bronze
#
# [470 rows x 11 columns]
# 1908
#                           Athlete  index    City  Edition      Sport  \
# 114                 ADAM, John M.   1688  London     1908    Sailing
# 142          ADLERSTRAHLE, Märtha   1875  London     1908     Tennis
# 177            AHEARNE, Timoty J.   1282  London     1908  Athletics
# 316    ALEXANDER, Gustav Bernhard   1552  London     1908   Lacrosse
# 317                 ALEXANDER, J.   1553  London     1908   Lacrosse
# ...                           ...    ...     ...      ...        ...
# 28347       WOODWARD, Vivian John   1381  London     1908   Football
# 28384       WRIGHT, Joseph George   1617  London     1908     Rowing
# 28758                ZACHAR, Imre   1166  London     1908   Aquatics
# 29160              ZULAWSKY, Béla   1347  London     1908    Fencing
# 29195              ZÜRNER, Albert   1138  London     1908   Aquatics
#
#       Discipline  NOC Gender                     Event Event_gender   Medal
# 114      Sailing  GBR    Men                       12m            X  Silver
# 142       Tennis  SWE  Women            singles indoor            W  Bronze
# 177    Athletics  GBR    Men               triple jump            M    Gold
# 316     Lacrosse  GBR    Men                  lacrosse            M  Silver
# 317     Lacrosse  GBR    Men                  lacrosse            M  Silver
# ...          ...  ...    ...                       ...          ...     ...
# 28347   Football  GBR    Men                  football            M    Gold
# 28384     Rowing  CAN    Men  eight with coxswain (8+)            M  Bronze
# 28758   Swimming  HUN    Men    4x200m freestyle relay            M  Silver
# 29160    Fencing  HUN    Men          sabre individual            M  Silver
# 29195     Diving  GER    Men            3m springboard            M    Gold
#
# [804 rows x 11 columns]
# 1912
#                     Athlete  index       City  Edition       Sport  \
# 14     AAS, Thomas Valentin   2601  Stockholm     1912     Sailing
# 69             ABERG, Georg   2114  Stockholm     1912   Athletics
# 70             ABERG, Georg   2141  Stockholm     1912   Athletics
# 86         ABRAHAMSEN, Isak   2354  Stockholm     1912  Gymnastics
# 117      ADAMS, Benjamin W.   2107  Stockholm     1912   Athletics
# ...                     ...    ...        ...      ...         ...
# 28878       ZBORZIL, Arthur   2760  Stockholm     1912      Tennis
# 29118         ZORZI, Angelo   2316  Stockholm     1912  Gymnastics
# 29196        ZÜRNER, Albert   1939  Stockholm     1912    Aquatics
# 29198       ÖRTEGREN, Ruben   2691  Stockholm     1912    Shooting
# 29204       ÖSTENSEN, Östen   2730  Stockholm     1912    Shooting
#
#         Discipline  NOC Gender                       Event Event_gender  \
# 14         Sailing  NOR    Men                          8m            X
# 69       Athletics  SWE    Men                   long jump            M
# 70       Athletics  SWE    Men                 triple jump            M
# 86     Artistic G.  NOR    Men           team, free system            M
# 117      Athletics  USA    Men         high jump, standing            M
# ...            ...  ...    ...                         ...          ...
# 28878       Tennis  AUT    Men                     doubles            M
# 29118  Artistic G.  ITA    Men            team competition            M
# 29196       Diving  GER    Men                10m platform            M
# 29198     Shooting  SWE    Men  50m small bore rifle, team            M
# 29204     Shooting  NOR    Men            free rifle, team            M
#
#         Medal
# 14       Gold
# 69     Bronze
# 70     Silver
# 86       Gold
# 117    Silver
# ...       ...
# 28878  Silver
# 29118    Gold
# 29196  Silver
# 29198  Silver
# 29204  Silver
#
# [885 rows x 11 columns]
# 1920
#                          Athlete  index     City  Edition       Sport  \
# 1          AALTONEN, Arvo Ossian   2849  Antwerp     1920    Aquatics
# 2          AALTONEN, Arvo Ossian   2852  Antwerp     1920    Aquatics
# 9               AANING, Alf Lied   3436  Antwerp     1920  Gymnastics
# 13                 AAS, Karl Jan   3437  Antwerp     1920  Gymnastics
# 62                    ABEL, Sten   3788  Antwerp     1920     Sailing
# ...                          ...    ...      ...      ...         ...
# 29206            ÖSTENSEN, Östen   4009  Antwerp     1920    Shooting
# 29207          ÖSTERVOLD, Henrik   3737  Antwerp     1920     Sailing
# 29208       ÖSTERVOLD, Jan Olsen   3738  Antwerp     1920     Sailing
# 29209  ÖSTERVOLD, Kristian Olsen   3739  Antwerp     1920     Sailing
# 29210       ÖSTERVOLD, Ole Olsen   3740  Antwerp     1920     Sailing
#
#         Discipline  NOC Gender              Event Event_gender   Medal
# 1         Swimming  FIN    Men  200m breaststroke            M  Bronze
# 2         Swimming  FIN    Men  400m breaststroke            M  Bronze
# 9      Artistic G.  NOR    Men  team, free system            M  Silver
# 13     Artistic G.  NOR    Men  team, free system            M  Silver
# 62         Sailing  NOR    Men                 7m            X  Silver
# ...            ...  ...    ...                ...          ...     ...
# 29206     Shooting  NOR    Men   free rifle, team            M  Silver
# 29207      Sailing  NOR    Men  12m (rating 1907)            X    Gold
# 29208      Sailing  NOR    Men  12m (rating 1907)            X    Gold
# 29209      Sailing  NOR    Men  12m (rating 1907)            X    Gold
# 29210      Sailing  NOR    Men  12m (rating 1907)            X    Gold
#
# [1298 rows x 11 columns]
# 1924
#                     Athlete  index   City  Edition          Sport  \
# 60            ABEGGLEN, Max   4564  Paris     1924       Football
# 81              ABRAHAM, F.   4782  Paris     1924          Rugby
# 84         ABRAHAMS, Harold   4236  Paris     1924      Athletics
# 85         ABRAHAMS, Harold   4281  Paris     1924      Athletics
# 181         AHLFORS, Anselm   4988  Paris     1924      Wrestling
# ...                     ...    ...    ...      ...            ...
# 28837        ZANDER, Robert   4541  Paris     1924       Football
# 29046   ZIBECHI, Alfredo J.   4562  Paris     1924       Football
# 29080           ZINGONE, P.   4563  Paris     1924       Football
# 29144  ZUCCHETTI, Francesco   4412  Paris     1924        Cycling
# 29178        ZWERINA, Anton   4958  Paris     1924  Weightlifting
#
#             Discipline  NOC Gender  \
# 60            Football  SUI    Men
# 81               Rugby  FRA    Men
# 84           Athletics  GBR    Men
# 85           Athletics  GBR    Men
# 181    Wrestling Gre-R  FIN    Men
# ...                ...  ...    ...
# 28837         Football  SWE    Men
# 29046         Football  URU    Men
# 29080         Football  URU    Men
# 29144    Cycling Track  ITA    Men
# 29178    Weightlifting  AUT    Men
#
#                                                   Event Event_gender   Medal
# 60                                             football            M  Silver
# 81                                                rugby            M  Silver
# 84                                                 100m            M    Gold
# 85                                         4x100m relay            M  Silver
# 181                               - 58kg (bantamweight)            M  Silver
# ...                                                 ...          ...     ...
# 28837                                          football            M  Bronze
# 29046                                          football            M    Gold
# 29080                                          football            M    Gold
# 29144                              Team Pursuit (4000m)            M    Gold
# 29178  60 - 67.5kg, one-two hand 5 events (lightweight)            M  Silver
#
# [884 rows x 11 columns]
# 1928
#                         Athlete  index       City  Edition       Sport  \
# 170         AGSTERIBBE, Estella   5463  Amsterdam     1928  Gymnastics
# 293    ALDERMAN, Frederick Pitt   5146  Amsterdam     1928   Athletics
# 357        ALLEN, Richard James   5512  Amsterdam     1928      Hockey
# 409                  AMANN, Max   5076  Amsterdam     1928    Aquatics
# 430          AMBROSETTI, Bianca   5475  Amsterdam     1928  Gymnastics
# ...                         ...    ...        ...      ...         ...
# 28738      YUSUF, Sayed Mohamed   5526  Amsterdam     1928      Hockey
# 28751          ZABIELSKI, Jerzy   5333  Amsterdam     1928     Fencing
# 28833             ZANDER, Erich   5511  Amsterdam     1928      Hockey
# 29115      ZORRILLA, Victoriano   5038  Amsterdam     1928    Aquatics
# 29164            ZUMELZU, A. B.   5411  Amsterdam     1928    Football
#
#         Discipline  NOC Gender             Event Event_gender   Medal
# 170    Artistic G.  NED  Women  team competition            W    Gold
# 293      Athletics  USA    Men      4x400m relay            M    Gold
# 357         Hockey  IND    Men            hockey            M    Gold
# 409     Water polo  GER    Men        water polo            M    Gold
# 430    Artistic G.  ITA  Women  team competition            W  Silver
# ...            ...  ...    ...               ...          ...     ...
# 28738       Hockey  IND    Men            hockey            M    Gold
# 28751      Fencing  POL    Men        sabre team            M  Bronze
# 28833       Hockey  GER    Men            hockey            M  Bronze
# 29115     Swimming  ARG    Men    400m freestyle            M    Gold
# 29164     Football  ARG    Men          football            M  Silver
#
# [710 rows x 11 columns]
# 1932
#                       Athlete  index         City  Edition      Sport  \
# 76      ABLOWICH, Edgar Allen   5857  Los Angeles     1932  Athletics
# 166           AGOSTONI, Carlo   6015  Los Angeles     1932    Fencing
# 167           AGOSTONI, Carlo   6000  Los Angeles     1932    Fencing
# 180    AHLBERG, Bruno Valfrid   5931  Los Angeles     1932     Boxing
# 185           AHLQVIST, Thure   5930  Los Angeles     1932     Boxing
# ...                       ...    ...          ...      ...        ...
# 28733          YUSA, Masanori   5772  Los Angeles     1932   Aquatics
# 28740     ZABALA, Juan Carlos   5905  Los Angeles     1932  Athletics
# 28858  ZAREMBA, Peter Timothy   5886  Los Angeles     1932  Athletics
# 29057         ZIGLARSKI, Hans   5924  Los Angeles     1932     Boxing
# 29109           ZOMBORI, Ödön   6289  Los Angeles     1932  Wrestling
#
#             Discipline  NOC Gender                           Event  \
# 76           Athletics  USA    Men                    4x400m relay
# 166            Fencing  ITA    Men                       épée team
# 167            Fencing  ITA    Men                 épée individual
# 180             Boxing  FIN    Men  61.24 - 66.68kg (welterweight)
# 185             Boxing  SWE    Men   57.15 - 61.24kg (lightweight)
# ...                ...  ...    ...                             ...
# 28733         Swimming  JPN    Men          4x200m freestyle relay
# 28740        Athletics  ARG    Men                        marathon
# 28858        Athletics  USA    Men                    hammer throw
# 29057           Boxing  GER    Men      50.8 - 54kg (bantamweight)
# 29109  Wrestling Free.  HUN    Men           - 56kg (bantamweight)
#
#       Event_gender   Medal
# 76               M    Gold
# 166              M  Silver
# 167              M  Bronze
# 180              M  Bronze
# 185              M  Silver
# ...            ...     ...
# 28733            M    Gold
# 28740            M    Gold
# 28858            M  Bronze
# 29057            M  Silver
# 29109            M  Silver
#
# [615 rows x 11 columns]
# 1936
#                    Athlete  index    City  Edition              Sport  \
# 27      ABAY-NEMES, Oszkar   6380  Berlin     1936           Aquatics
# 28           ABBA, Silvano   7003  Berlin     1936  Modern Pentathlon
# 112    ADAM, Gordon Belgum   7039  Berlin     1936             Rowing
# 115             ADAM, Otto   6739  Berlin     1936            Fencing
# 125       ADAMSKI, Herbert   7087  Berlin     1936             Rowing
# ...                    ...    ...     ...      ...                ...
# 28734       YUSA, Masanori   6349  Berlin     1936           Aquatics
# 28735       YUSA, Masanori   6387  Berlin     1936           Aquatics
# 28832        ZANDER, Erich   7002  Berlin     1936             Hockey
# 28887     ZEHETNER, Johann   6949  Berlin     1936           Handball
# 29108        ZOMBORI, Ödön   7163  Berlin     1936          Wrestling
#
#             Discipline  NOC Gender                                Event  \
# 27            Swimming  HUN    Men               4x200m freestyle relay
# 28     Modern Pentath.  ITA    Men               Individual competition
# 112             Rowing  USA    Men             eight with coxswain (8+)
# 115            Fencing  GER    Men                            foil team
# 125             Rowing  GER    Men  pair-oared shell with coxswain (2+)
# ...                ...  ...    ...                                  ...
# 28734         Swimming  JPN    Men                       100m freestyle
# 28735         Swimming  JPN    Men               4x200m freestyle relay
# 28832           Hockey  GER    Men                               hockey
# 28887         Handball  AUT    Men                             handball
# 29108  Wrestling Free.  HUN    Men                - 56kg (bantamweight)
#
#       Event_gender   Medal
# 27               M  Bronze
# 28               M  Bronze
# 112              M    Gold
# 115              M  Bronze
# 125              M    Gold
# ...            ...     ...
# 28734            M  Silver
# 28735            M    Gold
# 28832            M  Silver
# 28887            M  Silver
# 29108            M    Gold
#
# [875 rows x 11 columns]
# 1948
#                          Athlete  index    City  Edition       Sport  \
# 3       AALTONEN, Paavo Johannes   7773  London     1948  Gymnastics
# 4       AALTONEN, Paavo Johannes   7730  London     1948  Gymnastics
# 6       AALTONEN, Paavo Johannes   7709  London     1948  Gymnastics
# 7       AALTONEN, Paavo Johannes   7716  London     1948  Gymnastics
# 116                 ADAM, Pierre   7552  London     1948     Cycling
# ...                          ...    ...     ...      ...         ...
# 28868              ZATOPEK, Emil   7296  London     1948   Athletics
# 29071  ZIMMERMAN, Suzanne Winona   7221  London     1948    Aquatics
# 29077            ZIMONYI, Robert   7889  London     1948      Rowing
# 29130          ZSITNIK SR., Bela   7890  London     1948      Rowing
# 29152       ZUDDAS, Gianbattista   7469  London     1948      Boxing
#
#           Discipline  NOC Gender                                Event  \
# 3        Artistic G.  FIN    Men                                vault
# 4        Artistic G.  FIN    Men                     team competition
# 6        Artistic G.  FIN    Men                 individual all-round
# 7        Artistic G.  FIN    Men                         pommel horse
# 116    Cycling Track  FRA    Men                 Team Pursuit (4000m)
# ...              ...  ...    ...                                  ...
# 28868      Athletics  TCH    Men                               10000m
# 29071       Swimming  USA  Women                      100m backstroke
# 29077         Rowing  HUN    Men  pair-oared shell with coxswain (2+)
# 29130         Rowing  HUN    Men  pair-oared shell with coxswain (2+)
# 29152         Boxing  ITA    Men             51 - 54kg (bantamweight)
#
#       Event_gender   Medal
# 3                M    Gold
# 4                M    Gold
# 6                M  Bronze
# 7                M    Gold
# 116              M    Gold
# ...            ...     ...
# 28868            M    Gold
# 29071            W  Silver
# 29077            M  Bronze
# 29130            M  Bronze
# 29152            M  Silver
#
# [814 rows x 11 columns]
# 1952
#                         Athlete  index      City  Edition          Sport  \
# 5      AALTONEN, Paavo Johannes   8563  Helsinki     1952     Gymnastics
# 109       ACOSTA Y LARA, Martin   8240  Helsinki     1952     Basketball
# 134             ADKINS, Charles   8302  Helsinki     1952         Boxing
# 186         AHLUND, Olof "Olle"   8497  Helsinki     1952       Football
# 241            AKERLUND, Gunnar   8351  Helsinki     1952  Canoe / Kayak
# ...                         ...    ...       ...      ...            ...
# 29001            ZHILIN, Georgi   8706  Helsinki     1952         Rowing
# 29047      ZIEGLER, Edwin (Edy)   8359  Helsinki     1952        Cycling
# 29146      ZUCCONELLI, Vincenzo   8370  Helsinki     1952        Cycling
# 29188            ZYBINA, Galina   8235  Helsinki     1952      Athletics
# 29215         ÖSTRAND, Per-Olof   8051  Helsinki     1952       Aquatics
#
#             Discipline  NOC Gender                             Event  \
# 5          Artistic G.  FIN    Men                  team competition
# 109         Basketball  URU    Men                        basketball
# 134             Boxing  USA    Men  60 - 63.5kg (light-welterweight)
# 186           Football  SWE    Men                          football
# 241    Canoe / Kayak F  SWE    Men                        K-2 10000m
# ...                ...  ...    ...                               ...
# 29001           Rowing  URS    Men                double sculls (2x)
# 29047     Cycling Road  GER    Men              individual road race
# 29146     Cycling Road  ITA    Men                   team time trial
# 29188        Athletics  URS  Women                          shot put
# 29215         Swimming  SWE    Men                    400m freestyle
#
#       Event_gender   Medal
# 5                M  Bronze
# 109              M  Bronze
# 134              M    Gold
# 186              M  Bronze
# 241              M  Silver
# ...            ...     ...
# 29001            M  Silver
# 29047            M  Bronze
# 29146            M  Silver
# 29188            W    Gold
# 29215            M  Bronze
#
# [889 rows x 11 columns]
# 1956
#                  Athlete  index                   City  Edition  \
# 45          ABDUL, Hamid   9564  Melbourne / Stockholm     1956
# 72      ABERNETHY, Moira   8952  Melbourne / Stockholm     1956
# 154               AFRIKA   9293  Melbourne / Stockholm     1956
# 161        AGEEV, Viktor   8976  Melbourne / Stockholm     1956
# 179      AHKTAR, Hussain   9565  Melbourne / Stockholm     1956
# ...                  ...    ...                    ...      ...
# 29051  ZIELINSKI, Marian   9729  Melbourne / Stockholm     1956
# 29135       ZUB, Ryszard   9389  Melbourne / Stockholm     1956
# 29143     ZUBKOV, Viktor   9167  Melbourne / Stockholm     1956
# 29169      ZUZEJ, Marjan   9004  Melbourne / Stockholm     1956
# 29187     ZYBINA, Galina   9128  Melbourne / Stockholm     1956
#
#                Sport     Discipline  NOC Gender  \
# 45            Hockey         Hockey  PAK    Men
# 72          Aquatics       Swimming  RSA  Women
# 154       Equestrian       Dressage  EUA  Women
# 161         Aquatics     Water polo  URS    Men
# 179           Hockey         Hockey  PAK    Men
# ...              ...            ...  ...    ...
# 29051  Weightlifting  Weightlifting  POL    Men
# 29135        Fencing        Fencing  POL    Men
# 29143     Basketball     Basketball  URS    Men
# 29169       Aquatics     Water polo  YUG    Men
# 29187      Athletics      Athletics  URS  Women
#
#                                   Event Event_gender   Medal
# 45                               hockey            M  Silver
# 72               4x100m freestyle relay            W  Bronze
# 154                                team            X  Silver
# 161                          water polo            M  Bronze
# 179                              hockey            M  Silver
# ...                                 ...          ...     ...
# 29051  56 - 60kg, total (featherweight)            M  Bronze
# 29135                        sabre team            M  Silver
# 29143                        basketball            M  Silver
# 29169                        water polo            M  Silver
# 29187                          shot put            W  Silver
#
# [885 rows x 11 columns]
# 1960
#                 Athlete  index  City  Edition       Sport    Discipline  NOC  \
# 46         ABDUL, Hamid  10438  Rome     1960      Hockey        Hockey  PAK
# 47      ABDUL, Rashid I  10439  Rome     1960      Hockey        Hockey  PAK
# 52        ABDUL, Waheed  10440  Rome     1960      Hockey        Hockey  PAK
# 126      ADAMSKI, Jerzy  10100  Rome     1960      Boxing        Boxing  POL
# 138         ADLER, Egon  10175  Rome     1960     Cycling  Cycling Road  EUA
# ...                 ...    ...   ...      ...         ...           ...  ...
# 29133  ZSIVOTZKY, Gyula  10015  Rome     1960   Athletics     Athletics  HUN
# 29137      ZUB, Ryszard  10305  Rome     1960     Fencing       Fencing  POL
# 29142    ZUBKOV, Viktor  10084  Rome     1960  Basketball    Basketball  URS
# 29145  ZUCCHI, Giovanni  10531  Rome     1960      Rowing        Rowing  ITA
# 29192  ZÄHRINGER, Klaus  10596  Rome     1960    Shooting      Shooting  EUA
#
#       Gender                                Event Event_gender   Medal
# 46       Men                               hockey            M    Gold
# 47       Men                               hockey            M    Gold
# 52       Men                               hockey            M    Gold
# 126      Men            54 - 57kg (featherweight)            M  Silver
# 138      Men                      team time trial            M  Silver
# ...      ...                                  ...          ...     ...
# 29133    Men                         hammer throw            M  Silver
# 29137    Men                           sabre team            M  Silver
# 29142    Men                           basketball            M  Silver
# 29145    Men  four-oared shell with coxswain (4-)            M  Bronze
# 29192    Men   50m rifle 3 positions (3x40 shots)            M  Bronze
#
# [882 rows x 11 columns]
# 1964
#                         Athlete  index   City  Edition       Sport  \
# 44                 ABDUL, Hamid  11370  Tokyo     1964      Hockey
# 89              ABRAMOVA, Nelli  11603  Tokyo     1964  Volleyball
# 94         ABUKAWA-CHIBA, Ginko  11314  Tokyo     1964  Gymnastics
# 151               AEFFKE, Klaus  11444  Tokyo     1964      Rowing
# 162               AGEEV, Viktor  10785  Tokyo     1964    Aquatics
# ...                         ...    ...    ...      ...         ...
# 29078           ZIMONYI, Robert  11443  Tokyo     1964      Rowing
# 29105  ZOET, Hubertus Balthazar  11079  Tokyo     1964     Cycling
# 29131          ZSIVOTZKY, Gyula  10917  Tokyo     1964   Athletics
# 29136              ZUB, Ryszard  11207  Tokyo     1964     Fencing
# 29186            ZYBINA, Galina  10948  Tokyo     1964   Athletics
#
#          Discipline  NOC Gender                     Event Event_gender   Medal
# 44           Hockey  PAK    Men                    hockey            M  Silver
# 89       Volleyball  URS  Women                volleyball            W  Silver
# 94      Artistic G.  JPN  Women          team competition            W  Bronze
# 151          Rowing  EUA    Men  eight with coxswain (8+)            M  Silver
# 162      Water polo  URS    Men                water polo            M  Bronze
# ...             ...  ...    ...                       ...          ...     ...
# 29078        Rowing  USA    Men  eight with coxswain (8+)            M    Gold
# 29105  Cycling Road  NED    Men           team time trial            M    Gold
# 29131     Athletics  HUN    Men              hammer throw            M  Silver
# 29136       Fencing  POL    Men                sabre team            M  Bronze
# 29186     Athletics  URS  Women                  shot put            W  Bronze
#
# [1010 rows x 11 columns]
# 1968
#                        Athlete  index    City  Edition       Sport  \
# 48           ABDUL, Rashid III  12403  Mexico     1968      Hockey
# 219    AISHER, Robin Allingham  12520  Mexico     1968     Sailing
# 269           ALBARELLI, Fabio  12544  Mexico     1968     Sailing
# 279             ALBINI, Abramo  12481  Mexico     1968      Rowing
# 368    ALLHUSEN, Derek Swithin  12171  Mexico     1968  Equestrian
# ...                        ...    ...     ...      ...         ...
# 29111            ZORGA, Aljosa  12031  Mexico     1968  Basketball
# 29114            ZORN, Zachary  11772  Mexico     1968    Aquatics
# 29132         ZSIVOTZKY, Gyula  11958  Mexico     1968   Athletics
# 29147           ZUCHOLD, Erika  12366  Mexico     1968  Gymnastics
# 29148           ZUCHOLD, Erika  12387  Mexico     1968  Gymnastics
#
#         Discipline  NOC Gender                        Event Event_gender  \
# 48          Hockey  PAK    Men                       hockey            M
# 219        Sailing  GBR    Men                         5.5m            X
# 269        Sailing  ITA    Men  single-handed dinghy (Finn)            M
# 279         Rowing  ITA    Men   four without coxswain (4-)            M
# 368       Eventing  GBR    Men                   individual            X
# ...            ...  ...    ...                          ...          ...
# 29111   Basketball  YUG    Men                   basketball            M
# 29114     Swimming  USA    Men       4x100m freestyle relay            M
# 29132    Athletics  HUN    Men                 hammer throw            M
# 29147  Artistic G.  GDR  Women             team competition            W
# 29148  Artistic G.  GDR  Women                        vault            W
#
#         Medal
# 48       Gold
# 219    Bronze
# 269    Bronze
# 279    Bronze
# 368    Silver
# ...       ...
# 29111  Silver
# 29114    Gold
# 29132    Gold
# 29147  Bronze
# 29148  Silver
#
# [1031 rows x 11 columns]
# 1972
#                    Athlete  index    City  Edition       Sport  \
# 49       ABDUL, Rashid III  13551  Munich     1972      Hockey
# 53     ABDULBEKOV, Zagalav  13853  Munich     1972   Wrestling
# 61             ABEL, Irene  13459  Munich     1972  Gymnastics
# 77         ABOIMOV, Viktor  12804  Munich     1972    Aquatics
# 239           AKDAG, Vehbi  13854  Munich     1972   Wrestling
# ...                    ...    ...     ...      ...         ...
# 29089      ZIVKOVIC, Zoran  13501  Munich     1972    Handball
# 29113        ZORKO, Zdenko  13502  Munich     1972    Handball
# 29149       ZUCHOLD, Erika  13464  Munich     1972  Gymnastics
# 29150       ZUCHOLD, Erika  13467  Munich     1972  Gymnastics
# 29151       ZUCHOLD, Erika  13473  Munich     1972  Gymnastics
#
#             Discipline  NOC Gender                      Event Event_gender  \
# 49              Hockey  PAK    Men                     hockey            M
# 53     Wrestling Free.  URS    Men  57 - 62kg (featherweight)            M
# 61         Artistic G.  GDR  Women           team competition            W
# 77            Swimming  URS    Men     4x100m freestyle relay            M
# 239    Wrestling Free.  TUR    Men  57 - 62kg (featherweight)            M
# ...                ...  ...    ...                        ...          ...
# 29089         Handball  YUG    Men                   handball            M
# 29113         Handball  YUG    Men                   handball            M
# 29149      Artistic G.  GDR  Women           team competition            W
# 29150      Artistic G.  GDR  Women                uneven bars            W
# 29151      Artistic G.  GDR  Women                      vault            W
#
#         Medal
# 49     Silver
# 53       Gold
# 61     Silver
# 77     Silver
# 239    Silver
# ...       ...
# 29089    Gold
# 29113    Gold
# 29149  Silver
# 29150  Silver
# 29151  Silver
#
# [1185 rows x 11 columns]
# 1976
#                      Athlete  index      City  Edition              Sport  \
# 50         ABDUL, Rashid III  14743  Montreal     1976             Hockey
# 106           ACKERLEY, Paul  14759  Montreal     1976             Hockey
# 113               ADAM, Jiri  14824  Montreal     1976  Modern Pentathlon
# 153     AFRASILOAIA, Felicia  14956  Montreal     1976             Rowing
# 196      AHRENHOLZ, Brigitte  14881  Montreal     1976             Rowing
# ...                      ...    ...       ...      ...                ...
# 29100      ZOBELT, Roswietha  14965  Montreal     1976             Rowing
# 29103       ZOBER, Hannelore  14742  Montreal     1976           Handball
# 29104  ZOCH, Jacqueline Jean  14880  Montreal     1976             Rowing
# 29141           ZUBKO, Elena  14898  Montreal     1976             Rowing
# 29176    ZVYAGINTSEV, Viktor  14550  Montreal     1976           Football
#
#             Discipline  NOC Gender                                Event  \
# 50              Hockey  PAK    Men                               hockey
# 106             Hockey  NZL    Men                               hockey
# 113    Modern Pentath.  TCH    Men                     Team competition
# 153             Rowing  ROU  Women  quadruple sculls with coxswain (4x)
# 196             Rowing  GDR  Women             eight with coxswain (8+)
# ...                ...  ...    ...                                  ...
# 29100           Rowing  GDR  Women  quadruple sculls with coxswain (4x)
# 29103         Handball  GDR  Women                             handball
# 29104           Rowing  USA  Women             eight with coxswain (8+)
# 29141           Rowing  URS  Women             eight with coxswain (8+)
# 29176         Football  URS    Men                             football
#
#       Event_gender   Medal
# 50               M  Bronze
# 106              M    Gold
# 113              M  Silver
# 153              W  Bronze
# 196              W    Gold
# ...            ...     ...
# 29100            W    Gold
# 29103            W  Silver
# 29104            W  Bronze
# 29141            W  Silver
# 29176            M  Bronze
#
# [1305 rows x 11 columns]
# 1980
#                          Athlete  index    City  Edition      Sport  \
# 22     ABASCAL GARCIA, Alejandro  16390  Moscow     1980    Sailing
# 75                ABILOV, Ismail  16554  Moscow     1980  Wrestling
# 82                 ABRAHAM, Gary  15292  Moscow     1980   Aquatics
# 91            ABSAIDOV, Saipulla  16548  Moscow     1980  Wrestling
# 95      ABUSHAKHMETOV, Aleksandr  15794  Moscow     1980    Fencing
# ...                          ...    ...     ...      ...        ...
# 29162             ZULIANI, Mauro  15439  Moscow     1980  Athletics
# 29163      ZUMALACARREGUI, Jaime  16118  Moscow     1980     Hockey
# 29183       ZWOLINSKI, Krzysztof  15423  Moscow     1980  Athletics
# 29189             ZYCH, Boguslaw  15817  Moscow     1980    Fencing
# 29197        ÖRSTED, Hans-Henrik  15711  Moscow     1980    Cycling
#
#             Discipline  NOC Gender                     Event Event_gender  \
# 22             Sailing  ESP    Men           flying dutchman            X
# 75     Wrestling Free.  BUL    Men  74 - 82kg (middleweight)            M
# 82            Swimming  GBR    Men       4x100m medley relay            M
# 91     Wrestling Free.  URS    Men   62 - 68kg (lightweight)            M
# 95             Fencing  URS    Men                 épée team            M
# ...                ...  ...    ...                       ...          ...
# 29162        Athletics  ITA    Men              4x400m relay            M
# 29163           Hockey  ESP    Men                    hockey            M
# 29183        Athletics  POL    Men              4x100m relay            M
# 29189          Fencing  POL    Men                 foil team            M
# 29197    Cycling Track  DEN    Men        Individual Pursuit            M
#
#         Medal
# 22       Gold
# 75       Gold
# 82     Bronze
# 91       Gold
# 95     Bronze
# ...       ...
# 29162  Bronze
# 29163  Silver
# 29183  Silver
# 29189  Bronze
# 29197  Bronze
#
# [1387 rows x 11 columns]
# 1984
#                           Athlete  index         City  Edition       Sport  \
# 23     ABASCAL GOMEZ, Jose Manuel  16806  Los Angeles     1984   Athletics
# 32             ABBAGNALE, Carmine  17778  Los Angeles     1984      Rowing
# 37            ABBAGNALE, Giuseppe  17779  Los Angeles     1984      Rowing
# 42                    ABDO, Reema  16709  Los Angeles     1984    Aquatics
# 51               ABDUL, Rashid IV  17531  Los Angeles     1984      Hockey
# ...                           ...    ...          ...      ...         ...
# 29079              ZINDLER, Petra  16670  Los Angeles     1984    Aquatics
# 29090                ZIZIC, Rajko  16961  Los Angeles     1984  Basketball
# 29112             ZORKIC, Nebojsa  16962  Los Angeles     1984  Basketball
# 29124              ZOVKO, Zdravko  17458  Los Angeles     1984    Handball
# 29128              ZSCHERPE, Iris  16688  Los Angeles     1984    Aquatics
#
#        Discipline  NOC Gender                                Event  \
# 23      Athletics  ESP    Men                                1500m
# 32         Rowing  ITA    Men  pair-oared shell with coxswain (2+)
# 37         Rowing  ITA    Men  pair-oared shell with coxswain (2+)
# 42       Swimming  CAN  Women                  4x100m medley relay
# 51         Hockey  PAK    Men                               hockey
# ...           ...  ...    ...                                  ...
# 29079    Swimming  FRG  Women               400m individual medley
# 29090  Basketball  YUG    Men                           basketball
# 29112  Basketball  YUG    Men                           basketball
# 29124    Handball  YUG    Men                             handball
# 29128    Swimming  FRG  Women               4x100m freestyle relay
#
#       Event_gender   Medal
# 23               M  Bronze
# 32               M    Gold
# 37               M    Gold
# 42               W  Bronze
# 51               M    Gold
# ...            ...     ...
# 29079            W  Bronze
# 29090            M  Bronze
# 29112            M  Bronze
# 29124            M    Gold
# 29128            W  Bronze
#
# [1459 rows x 11 columns]
# 1988
#                       Athlete  index   City  Edition          Sport  \
# 10      AARDENBURG, Willemien  19062  Seoul     1988         Hockey
# 30        ABBAGNALE, Agostino  19283  Seoul     1988         Rowing
# 33         ABBAGNALE, Carmine  19273  Seoul     1988         Rowing
# 35        ABBAGNALE, Giuseppe  19274  Seoul     1988         Rowing
# 78            ABRAHAM, Attila  18609  Seoul     1988  Canoe / Kayak
# ...                       ...    ...    ...      ...            ...
# 29070        ZILPORYTE, Laima  18632  Seoul     1988        Cycling
# 29074     ZIMMERMANN, Kathrin  18095  Seoul     1988       Aquatics
# 29161  ZULIANELLO, Claudio F.  19446  Seoul     1988     Volleyball
# 29193         ZÜHLKE, Steffen  19282  Seoul     1988         Rowing
# 29194          ZÜLOW, Andreas  18534  Seoul     1988         Boxing
#
#             Discipline  NOC Gender                                   Event  \
# 10              Hockey  NED  Women                                  hockey
# 30              Rowing  ITA    Men  quadruple sculls without coxswain (4x)
# 33              Rowing  ITA    Men     pair-oared shell with coxswain (2+)
# 35              Rowing  ITA    Men     pair-oared shell with coxswain (2+)
# 78     Canoe / Kayak F  HUN    Men                  K-4 1000m (kayak four)
# ...                ...  ...    ...                                     ...
# 29070     Cycling Road  URS  Women                    individual road race
# 29074         Swimming  GDR  Women                         200m backstroke
# 29161       Volleyball  ARG    Men                              volleyball
# 29193           Rowing  GDR    Men  quadruple sculls without coxswain (4x)
# 29194           Boxing  GDR    Men                 57 - 60kg (lightweight)
#
#       Event_gender   Medal
# 10               W  Bronze
# 30               M    Gold
# 33               M    Gold
# 35               M    Gold
# 78               M    Gold
# ...            ...     ...
# 29070            W  Bronze
# 29074            W  Silver
# 29161            M  Bronze
# 29193            M  Bronze
# 29194            M    Gold
#
# [1546 rows x 11 columns]
# 1992
#                    Athlete  index       City  Edition       Sport  Discipline  \
# 26             ABAY, Peter  20477  Barcelona     1992     Fencing     Fencing
# 34      ABBAGNALE, Carmine  20970  Barcelona     1992      Rowing      Rowing
# 36     ABBAGNALE, Giuseppe  20971  Barcelona     1992      Rowing      Rowing
# 58      ABDUVALIEV, Andrey  19984  Barcelona     1992   Athletics   Athletics
# 59            ABEBE, Addis  19849  Barcelona     1992   Athletics   Athletics
# ...                    ...    ...        ...      ...         ...         ...
# 29110      ZOODSMA, Ronald  21175  Barcelona     1992  Volleyball  Volleyball
# 29170       ZVEGELJ, Denis  20860  Barcelona     1992      Rowing      Rowing
# 29173     ZVEREVA, Natalya  21128  Barcelona     1992      Tennis      Tennis
# 29180      ZWERVER, Ronald  21176  Barcelona     1992  Volleyball  Volleyball
# 29185  ZWOLLE, Hendrik Jan  20866  Barcelona     1992      Rowing      Rowing
#
#        NOC Gender                                Event Event_gender   Medal
# 26     HUN    Men                           sabre team            M  Silver
# 34     ITA    Men  pair-oared shell with coxswain (2+)            M  Silver
# 36     ITA    Men  pair-oared shell with coxswain (2+)            M  Silver
# 58     EUN    Men                         hammer throw            M    Gold
# 59     ETH    Men                               10000m            M  Bronze
# ...    ...    ...                                  ...          ...     ...
# 29110  NED    Men                           volleyball            M  Silver
# 29170  SLO    Men                    coxless pair (2-)            M  Bronze
# 29173  EUN  Women                              doubles            W  Bronze
# 29180  NED    Men                           volleyball            M  Silver
# 29185  NED    Men                   double sculls (2x)            M  Bronze
#
# [1705 rows x 11 columns]
# 1996
#                     Athlete  index     City  Edition       Sport  \
# 11        AARDEWIJN, Pepijn  22769  Atlanta     1996      Rowing
# 12     AARONES, Ann Kristin  22267  Atlanta     1996    Football
# 20       ABARCA, Jose Maria  21538  Atlanta     1996    Aquatics
# 31      ABBAGNALE, Agostino  22677  Atlanta     1996      Rowing
# 54        ABDULLAYEV, Namig  23109  Atlanta     1996   Wrestling
# ...                     ...    ...      ...      ...         ...
# 29157  ZUKAUSKAS, Mindaugas  21863  Atlanta     1996  Basketball
# 29172       ZVEREVA, Ellina  21720  Atlanta     1996   Athletics
# 29181       ZWERVER, Ronald  23022  Atlanta     1996  Volleyball
# 29182       ZWIERS, Claudia  22643  Atlanta     1996        Judo
# 29184   ZWOLLE, Hendrik Jan  22704  Atlanta     1996      Rowing
#
#             Discipline  NOC Gender                           Event  \
# 11              Rowing  NED    Men  lightweight double sculls (2x)
# 12            Football  NOR  Women                        football
# 20          Water polo  ESP    Men                      water polo
# 31              Rowing  ITA    Men              double sculls (2x)
# 54     Wrestling Free.  AZE    Men           48 - 52kg (flyweight)
# ...                ...  ...    ...                             ...
# 29157       Basketball  LTU    Men                      basketball
# 29172        Athletics  BLR  Women                    discus throw
# 29181       Volleyball  NED    Men                      volleyball
# 29182             Judo  NED  Women        61 - 66kg (middleweight)
# 29184           Rowing  NED    Men        eight with coxswain (8+)
#
#       Event_gender   Medal
# 11               M  Silver
# 12               W  Bronze
# 20               M    Gold
# 31               M    Gold
# 54               M  Silver
# ...            ...     ...
# 29157            M  Bronze
# 29172            W  Bronze
# 29181            M    Gold
# 29182            W  Bronze
# 29184            M    Gold
#
# [1859 rows x 11 columns]
# 2000
#                           Athlete  index    City  Edition       Sport  \
# 19          ABANDA ETONG, Patrice  24202  Sydney     2000    Football
# 29            ABBAGNALE, Agostino  24757  Sydney     2000      Rowing
# 43     ABDOOLLAYEV, Mahammatkodir  23892  Sydney     2000      Boxing
# 55              ABDULLAYEV, Namig  25129  Sydney     2000   Wrestling
# 56           ABDUR-RAHIM, Shareef  23806  Sydney     2000  Basketball
# ...                           ...    ...     ...      ...         ...
# 29129           ZSEMBERY, Tamasne  24480  Sydney     2000    Handball
# 29154           ZUIJDWEG, Martijn  23342  Sydney     2000    Aquatics
# 29156        ZUKAUSKAS, Eurelijus  23805  Sydney     2000  Basketball
# 29171             ZVEREVA, Ellina  23644  Sydney     2000   Athletics
# 29190              ZYKINA, Olesya  23611  Sydney     2000   Athletics
#
#             Discipline  NOC Gender                                   Event  \
# 19            Football  CMR    Men                                football
# 29              Rowing  ITA    Men  quadruple sculls without coxswain (4x)
# 43              Boxing  UZB    Men        60 - 63.5kg (light-welterweight)
# 55     Wrestling Free.  AZE    Men                               48 - 54kg
# 56          Basketball  USA    Men                              basketball
# ...                ...  ...    ...                                     ...
# 29129         Handball  HUN  Women                                handball
# 29154         Swimming  NED    Men                  4x200m freestyle relay
# 29156       Basketball  LTU    Men                              basketball
# 29171        Athletics  BLR  Women                            discus throw
# 29190        Athletics  RUS  Women                            4x400m relay
#
#       Event_gender   Medal
# 19               M    Gold
# 29               M    Gold
# 43               M    Gold
# 55               M    Gold
# 56               M    Gold
# ...            ...     ...
# 29129            W  Silver
# 29154            M  Bronze
# 29156            M  Bronze
# 29171            W    Gold
# 29190            W  Bronze
#
# [2015 rows x 11 columns]
# 2004
#                    Athlete  index    City  Edition       Sport  \
# 21           ABAS, Stephen  27125  Athens     2004   Wrestling
# 24       ABASSOVA, Tamilla  26049  Athens     2004     Cycling
# 41           ABDALLAH, Nia  26960  Athens     2004   Taekwondo
# 83         ABRAHAMIAN, Ara  27167  Athens     2004   Wrestling
# 88          ABRAMOV, Pavel  27004  Athens     2004  Volleyball
# ...                    ...    ...     ...      ...         ...
# 29168        ZUYEV, Viktar  25923  Athens     2004      Boxing
# 29174     ZVIADAURI, Zurab  26622  Athens     2004        Judo
# 29177         ZWEHL, Julia  26556  Athens     2004      Hockey
# 29179  ZWERING, Klaas-Erik  25297  Athens     2004    Aquatics
# 29191       ZYKINA, Olesya  25639  Athens     2004   Athletics
#
#             Discipline  NOC Gender                     Event Event_gender  \
# 21     Wrestling Free.  USA    Men                    - 55kg            M
# 24       Cycling Track  RUS  Women                    sprint            W
# 41           Taekwondo  USA  Women                49 - 57 kg            W
# 83     Wrestling Gre-R  SWE    Men                 74 - 84kg            M
# 88          Volleyball  RUS    Men                volleyball            M
# ...                ...  ...    ...                       ...          ...
# 29168           Boxing  BLR    Men   81 - 91kg (heavyweight)            M
# 29174             Judo  GEO    Men  81 - 90kg (middleweight)            M
# 29177           Hockey  GER  Women                    hockey            W
# 29179         Swimming  NED    Men    4x100m freestyle relay            M
# 29191        Athletics  RUS  Women              4x400m relay            W
#
#         Medal
# 21     Silver
# 24     Silver
# 41     Silver
# 83     Silver
# 88     Bronze
# ...       ...
# 29168  Silver
# 29174    Gold
# 29177    Gold
# 29179  Silver
# 29191  Silver
#
# [1998 rows x 11 columns]
# 2008
#                               Athlete  index     City  Edition          Sport  \
# 8                    AAMODT, Ragnhild  28460  Beijing     2008       Handball
# 15                   ABAJO, Jose Luis  28134  Beijing     2008        Fencing
# 16                   ABAKUMOVA, Maria  27691  Beijing     2008      Athletics
# 17                ABALMASAU, Aliaksei  27983  Beijing     2008  Canoe / Kayak
# 18                         ABALO, Luc  28417  Beijing     2008       Handball
# ...                               ...    ...      ...      ...            ...
# 29134  ZU-SAYN WITTGENSTEIN, Nathalie  28095  Beijing     2008     Equestrian
# 29139                  ZUBARI, Shahar  28819  Beijing     2008        Sailing
# 29140                 ZUBCIC, Martina  28977  Beijing     2008      Taekwondo
# 29153                  ZUEVA, Natalia  28387  Beijing     2008     Gymnastics
# 29175                 ZVONAREVA, Vera  29007  Beijing     2008         Tennis
#
#             Discipline  NOC Gender                   Event Event_gender  \
# 8             Handball  NOR  Women                handball            W
# 15             Fencing  ESP    Men         épée individual            M
# 16           Athletics  RUS  Women           javelin throw            W
# 17     Canoe / Kayak F  BLR    Men  K-4 1000m (kayak four)            M
# 18            Handball  FRA    Men                handball            M
# ...                ...  ...    ...                     ...          ...
# 29134         Dressage  DEN  Women                    team            X
# 29139          Sailing  ISR    Men       RS:X - Windsurfer            M
# 29140        Taekwondo  CRO  Women              49 - 57 kg            W
# 29153      Rhythmic G.  RUS  Women       group competition            W
# 29175           Tennis  RUS  Women                 singles            W
#
#         Medal
# 8        Gold
# 15     Bronze
# 16     Silver
# 17       Gold
# 18       Gold
# ...       ...
# 29134  Bronze
# 29139  Bronze
# 29140  Bronze
# 29153    Gold
# 29175  Bronze
#
# [2042 rows x 11 columns]

# %%
oo.groupby(['Edition', 'NOC', 'Medal']).agg({'Edition': ['min', 'max','count']})
# Out:
#                    Edition
#                        min   max count
# Edition NOC Medal
# 1896    AUS Gold      1896  1896     2
#         AUT Bronze    1896  1896     2
#             Gold      1896  1896     2
#             Silver    1896  1896     1
#         DEN Bronze    1896  1896     3
# ...                    ...   ...   ...
# 2008    UZB Silver    2008  2008     2
#         VEN Bronze    2008  2008     1
#         VIE Silver    2008  2008     1
#         ZIM Gold      2008  2008     1
#             Silver    2008  2008     3
#
# [2356 rows x 3 columns]

# %%
oo.loc[oo.Athlete=='LEWIS, Carl'].groupby('Athlete').agg({'Edition': ['min', 'max','count']})
# Out:
#             Edition
#                 min   max count
# Athlete
# LEWIS, Carl    1984  1996    10

# %%
oo.groupby('Edition').size().plot()
# Out:
# <AxesSubplot:xlabel='Edition'>

# %%
oo.groupby('NOC').agg({'Edition': ['count', 'min', 'max']})
# Out:
#     Edition
#       count   min   max
# NOC
# AFG       1  2008  2008
# AHO       1  1988  1988
# ALG      14  1984  2008
# ANZ      29  1908  1912
# ARG     239  1924  2008
# ..      ...   ...   ...
# VIE       2  2000  2008
# YUG     435  1924  2000
# ZAM       2  1984  1996
# ZIM      23  1980  2008
# ZZX      48  1896  1904
#
# [138 rows x 3 columns]

# %%
oo
# Out:
#                         Athlete  index      City  Edition       Sport  \
# 0                  AABYE, Edgar    651     Paris     1900  Tug of War
# 1         AALTONEN, Arvo Ossian   2849   Antwerp     1920    Aquatics
# 2         AALTONEN, Arvo Ossian   2852   Antwerp     1920    Aquatics
# 3      AALTONEN, Paavo Johannes   7773    London     1948  Gymnastics
# 4      AALTONEN, Paavo Johannes   7730    London     1948  Gymnastics
# ...                         ...    ...       ...      ...         ...
# 29211                ÖSTMO, Ole    603     Paris     1900    Shooting
# 29212                ÖSTMO, Ole    608     Paris     1900    Shooting
# 29213                ÖSTMO, Ole    621     Paris     1900    Shooting
# 29214                ÖSTMO, Ole    596     Paris     1900    Shooting
# 29215         ÖSTRAND, Per-Olof   8051  Helsinki     1952    Aquatics
#
#         Discipline  NOC Gender                          Event Event_gender  \
# 0       Tug of War  ZZX    Men                     tug of war            M
# 1         Swimming  FIN    Men              200m breaststroke            M
# 2         Swimming  FIN    Men              400m breaststroke            M
# 3      Artistic G.  FIN    Men                          vault            M
# 4      Artistic G.  FIN    Men               team competition            M
# ...            ...  ...    ...                            ...          ...
# 29211     Shooting  NOR    Men        army rifle, 300m, prone            M
# 29212     Shooting  NOR    Men     army rifle, 300m, standing            M
# 29213     Shooting  NOR    Men               free rifle, team            M
# 29214     Shooting  NOR    Men  army rifle, 300m, 3 positions            M
# 29215     Swimming  SWE    Men                 400m freestyle            M
#
#         Medal
# 0        Gold
# 1      Bronze
# 2      Bronze
# 3        Gold
# 4        Gold
# ...       ...
# 29211  Bronze
# 29212  Silver
# 29213  Silver
# 29214  Bronze
# 29215  Bronze
#
# [29216 rows x 11 columns]

# %%
oo[(oo.Edition ==2008) & (oo.Event=='100m')]
# Out:
#                   Athlete  index     City  Edition      Sport Discipline  NOC  \
# 2452          BOLT, Usain  27552  Beijing     2008  Athletics  Athletics  JAM
# 5831          DIX, Walter  27551  Beijing     2008  Athletics  Athletics  USA
# 7529   FRASER, Shelly-ann  27554  Beijing     2008  Athletics  Athletics  JAM
# 23536    SIMPSON, Sherone  27555  Beijing     2008  Athletics  Athletics  JAM
# 24432     STEWART, Kerron  27556  Beijing     2008  Athletics  Athletics  JAM
# 25580   THOMPSON, Richard  27553  Beijing     2008  Athletics  Athletics  TRI
#
#       Gender Event Event_gender   Medal
# 2452     Men  100m            M    Gold
# 5831     Men  100m            M  Bronze
# 7529   Women  100m            W    Gold
# 23536  Women  100m            W  Silver
# 24432  Women  100m            W  Silver
# 25580    Men  100m            M  Silver

# %%
oo.stack()
# Out:
# 0      Athlete           AABYE, Edgar
#        index                      651
#        City                     Paris
#        Edition                   1900
#        Sport               Tug of War
#                             ...
# 29215  NOC                        SWE
#        Gender                     Men
#        Event           400m freestyle
#        Event_gender                 M
#        Medal                   Bronze
# Length: 321376, dtype: object

# %%
oo
# Out:
#                         Athlete  index      City  Edition       Sport  \
# 0                  AABYE, Edgar    651     Paris     1900  Tug of War
# 1         AALTONEN, Arvo Ossian   2849   Antwerp     1920    Aquatics
# 2         AALTONEN, Arvo Ossian   2852   Antwerp     1920    Aquatics
# 3      AALTONEN, Paavo Johannes   7773    London     1948  Gymnastics
# 4      AALTONEN, Paavo Johannes   7730    London     1948  Gymnastics
# ...                         ...    ...       ...      ...         ...
# 29211                ÖSTMO, Ole    603     Paris     1900    Shooting
# 29212                ÖSTMO, Ole    608     Paris     1900    Shooting
# 29213                ÖSTMO, Ole    621     Paris     1900    Shooting
# 29214                ÖSTMO, Ole    596     Paris     1900    Shooting
# 29215         ÖSTRAND, Per-Olof   8051  Helsinki     1952    Aquatics
#
#         Discipline  NOC Gender                          Event Event_gender  \
# 0       Tug of War  ZZX    Men                     tug of war            M
# 1         Swimming  FIN    Men              200m breaststroke            M
# 2         Swimming  FIN    Men              400m breaststroke            M
# 3      Artistic G.  FIN    Men                          vault            M
# 4      Artistic G.  FIN    Men               team competition            M
# ...            ...  ...    ...                            ...          ...
# 29211     Shooting  NOR    Men        army rifle, 300m, prone            M
# 29212     Shooting  NOR    Men     army rifle, 300m, standing            M
# 29213     Shooting  NOR    Men               free rifle, team            M
# 29214     Shooting  NOR    Men  army rifle, 300m, 3 positions            M
# 29215     Swimming  SWE    Men                 400m freestyle            M
#
#         Medal
# 0        Gold
# 1      Bronze
# 2      Bronze
# 3        Gold
# 4        Gold
# ...       ...
# 29211  Bronze
# 29212  Silver
# 29213  Silver
# 29214  Bronze
# 29215  Bronze
#
# [29216 rows x 11 columns]

# %%
oo.groupby(['Athlete', 'Medal']).size().unstack('Medal', fill_value=0)
# Out:
# Medal                      Bronze  Gold  Silver
# Athlete
# AABYE, Edgar                    0     1       0
# AALTONEN, Arvo Ossian           2     0       0
# AALTONEN, Paavo Johannes        2     3       0
# AAMODT, Ragnhild                0     1       0
# AANING, Alf Lied                0     0       1
# ...                           ...   ...     ...
# ÖSTERVOLD, Jan Olsen            0     1       0
# ÖSTERVOLD, Kristian Olsen       0     1       0
# ÖSTERVOLD, Ole Olsen            0     1       0
# ÖSTMO, Ole                      2     0       2
# ÖSTRAND, Per-Olof               1     0       0
#
# [21413 rows x 3 columns]

# %%
g = oo.groupby(['Athlete', 'Medal']).size().unstack('Medal', fill_value=0)
g.sort_values(['Gold', 'Silver', 'Bronze'], ascending = False)[['Gold', 'Silver', 'Bronze']].head().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Athlete'>

# %%
import matplotlib as plt
import pandas as pd
import seaborn as sns

# %%
oo = pd.read_csv('./desktop/olympics.csv', skiprows=4)
oo.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
lo = oo[oo.Edition== 2008]
lo
# Out:
#           City  Edition      Sport       Discipline               Athlete  \
# 27174  Beijing     2008   Aquatics           Diving        GALPERIN, Gleb
# 27175  Beijing     2008   Aquatics           Diving      MITCHAM, Matthew
# 27176  Beijing     2008   Aquatics           Diving           ZHOU, Luxin
# 27177  Beijing     2008   Aquatics           Diving             WANG, Xin
# 27178  Beijing     2008   Aquatics           Diving          CHEN, Ruolin
# ...        ...      ...        ...              ...                   ...
# 29211  Beijing     2008  Wrestling  Wrestling Gre-R        ENGLICH, Mirko
# 29212  Beijing     2008  Wrestling  Wrestling Gre-R  MIZGAITIS, Mindaugas
# 29213  Beijing     2008  Wrestling  Wrestling Gre-R       PATRIKEEV, Yuri
# 29214  Beijing     2008  Wrestling  Wrestling Gre-R         LOPEZ, Mijain
# 29215  Beijing     2008  Wrestling  Wrestling Gre-R        BAROEV, Khasan
#
#        NOC Gender         Event Event_gender   Medal
# 27174  RUS    Men  10m platform            M  Bronze
# 27175  AUS    Men  10m platform            M    Gold
# 27176  CHN    Men  10m platform            M  Silver
# 27177  CHN  Women  10m platform            W  Bronze
# 27178  CHN  Women  10m platform            W    Gold
# ...    ...    ...           ...          ...     ...
# 29211  GER    Men     84 - 96kg            M  Silver
# 29212  LTU    Men    96 - 120kg            M  Bronze
# 29213  ARM    Men    96 - 120kg            M  Bronze
# 29214  CUB    Men    96 - 120kg            M    Gold
# 29215  RUS    Men    96 - 120kg            M  Silver
#
# [2042 rows x 10 columns]

# %%
g=lo.groupby(['NOC', 'Medal']).size().unstack('Medal',fill_value=0)
g.sort_values(['Gold', 'Silver', 'Bronze'], ascending=False)[['Gold', 'Silver', 'Bronze']]
# Out:
# Medal  Gold  Silver  Bronze
# NOC
# USA     125     109      81
# CHN      74      53      57
# RUS      43      44      56
# GER      42      16      43
# KOR      41      11      26
# ..      ...     ...     ...
# ISR       0       0       1
# MDA       0       0       1
# MRI       0       0       1
# TOG       0       0       1
# VEN       0       0       1
#
# [86 rows x 3 columns]

# %%
sns.heatmap(g)
# Out:
# <AxesSubplot:xlabel='Medal', ylabel='NOC'>

# %%
g = g.transpose()

# %%
g
# Out:
# NOC     AFG  ALG  ARG  ARM  AUS  AUT  AZE  BAH  BEL  BLR  ...  TPE  TRI  TUN  \
# Medal                                                     ...
# Bronze    1    1   31    6   76    2    4    1    0   17  ...    4    0    0
# Gold      0    0   20    0   31    0    1    0    1    8  ...    0    0    1
# Silver    0    1    0    0   42    1    2    4    4    5  ...    0    5    0
#
# NOC     TUR  UKR  USA  UZB  VEN  VIE  ZIM
# Medal
# Bronze    3   16   81    3    1    0    0
# Gold      1   10  125    1    0    0    1
# Silver    4    5  109    2    0    1    3
#
# [3 rows x 86 columns]

# %%
sns.heatmap(g)
# Out:
# <AxesSubplot:xlabel='NOC', ylabel='Medal'>

# %%
g = oo.groupby(['Athlete', 'Medal']).size().unstack('Medal', fill_value=0)
g.sort_values(['Gold', 'Silver', 'Bronze'], ascending = False)[['Gold', 'Silver', 'Bronze']].head().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Athlete'>

# %%
sns.color_palette()
# Out:
# [(0.12156862745098039, 0.4666666666666667, 0.7058823529411765),
#  (1.0, 0.4980392156862745, 0.054901960784313725),
#  (0.17254901960784313, 0.6274509803921569, 0.17254901960784313),
#  (0.8392156862745098, 0.15294117647058825, 0.1568627450980392),
#  (0.5803921568627451, 0.403921568627451, 0.7411764705882353),
#  (0.5490196078431373, 0.33725490196078434, 0.29411764705882354),
#  (0.8901960784313725, 0.4666666666666667, 0.7607843137254902),
#  (0.4980392156862745, 0.4980392156862745, 0.4980392156862745),
#  (0.7372549019607844, 0.7411764705882353, 0.13333333333333333),
#  (0.09019607843137255, 0.7450980392156863, 0.8117647058823529)]

# %%
from matplotlib.colors import ListedColormap
gsb = ['#dbb40c', '#c5c9c7', '#a87900']
sns.palplot(sns.color_palette(gsb))

# %%
my_gsb = ListedColormap(sns.color_palette(gsb))
g = oo.groupby(['Athlete', 'Medal']).size().unstack('Medal', fill_value=0)
g = g.sort_values(['Gold', 'Silver', 'Bronze'], ascending = False)[['Gold', 'Silver', 'Bronze']].head()
g.plot(kind='bar', colormap=my_gsb)
# Out:
# <AxesSubplot:xlabel='Athlete'>
